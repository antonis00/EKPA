# %% [markdown]
# <a href="https://colab.research.google.com/github/antonis00/EKPA/blob/main/FinalEyeDetectionSavedModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymovements
import pymovements as pm
dataset = pm.Dataset("GazeBaseVR", path='data/GazeBaseVR')
dataset.download()
dataset.load()
# Out:
# Collecting pymovements
#   Downloading pymovements-0.18.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting matplotlib<3.9,>=3.8.0 (from pymovements)
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pymovements) (1.26.4)
# Requirement already satisfied: pandas<3,>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pymovements) (2.1.4)
# Requirement already satisfied: polars<0.20.3,>=0.20.1 in /usr/local/lib/python3.10/dist-packages (from pymovements) (0.20.2)
# Requirement already satisfied: pyarrow<16,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from pymovements) (14.0.2)
# Requirement already satisfied: pyopenssl<25.0.0,>=16.0.0 in /usr/local/lib/python3.10/dist-packages (from pymovements) (24.2.1)
# Requirement already satisfied: scipy<2,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from pymovements) (1.13.1)
# Requirement already satisfied: tqdm<5,>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from pymovements) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pymovements) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.8.0->pymovements) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=2.1.4->pymovements) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=2.1.4->pymovements) (2024.1)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /usr/local/lib/python3.10/dist-packages (from pyopenssl<25.0.0,>=16.0.0->pymovements) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<44,>=41.0.5->pyopenssl<25.0.0,>=16.0.0->pymovements) (1.17.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.9,>=3.8.0->pymovements) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyopenssl<25.0.0,>=16.0.0->pymovements) (2.22)
# Downloading pymovements-0.18.0-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 kB 1.8 MB/s eta 0:00:00
# Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 102.7 MB/s eta 0:00:00
# Installing collected packages: matplotlib, pymovements
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed matplotlib-3.8.4 pymovements-0.18.0
# Downloading https://figshare.com/ndownloader/files/38844024 to data/GazeBaseVR/downloads/gazebasevr.zip
# gazebasevr.zip: 0.00B [00:00, ?B/s]
# Checking integrity of gazebasevr.zip
# Extracting gazebasevr.zip to data/GazeBaseVR/raw
#   0%|          | 0/5020 [00:00<?, ?it/s]

# %% [markdown]
# # Eye Movement-Based User Identification
#
# ## Introduction
#
# This notebook demonstrates a machine learning approach to identify users based on their eye movement patterns across different tasks. We use data collected from participants performing five distinct eye-tracking (ET) tasks:
#
# 1. Vergence task (VRG)
# 2. Horizontal smooth pursuit task (PUR)
# 3. Video-viewing task (VID)
# 4. Self-paced reading task (TEX)
# 5. Random oblique saccade task (RAN)
#
# ## Data Processing and Feature Extraction
#
# We extract a comprehensive set of features from the eye-tracking data for each task. The features are calculated both globally and for multiple time-based portions of each task.
#
# ### Velocity Calculation
#
# Before feature extraction, we calculate the velocity of eye movements using the Savitzky-Golay filter:
#  dataset.pos2vel(method='savitzky_golay', degree=2, window_length=7)
# *italicised text*
#  This method applies a Savitzky-Golay filter to smooth the position data and calculate velocities. It uses a polynomial of degree 2 and a window length of 7 samples, which helps to reduce noise while preserving the underlying signal characteristics.
#
# ### Extracted Features
#
# For each portion and globally:
#
# 1. **Velocity Statistics**:
#    - Mean velocity
#    - Standard deviation of velocity
#    - Maximum velocity
#    - Skewness of velocity distribution
#    - Kurtosis of velocity distribution
#
# 2. **Position Statistics**:
#    - Mean X and Y positions
#    - Standard deviation of X and Y positions
#
# 3. **Target Position** (if available):
#    - Mean X and Y target positions
#    - Standard deviation of X and Y target positions
#
# 4. **Saccade and Fixation Metrics**:
#    - Saccade rate (proportion of samples above saccade threshold)
#    - Fixation rate (proportion of samples below fixation threshold)
#
# 5. **Task Duration**:
#    - Total number of samples in the task
#
# ## Model Architecture
#
# We use a Multi-Layer Perceptron (MLP) classifier with the following structure:
# - Input layer (size depends on the number of features)
# - Hidden layers: 64 units, 32 units, 16 units
# - Output layer (size equals the number of unique users)
# - A skip connection from input to output for improved learning
#
# ## Training Process
#
# The model is trained using:
# - Adam optimizer with a learning rate of 0.05
# - Cross-entropy loss function
# - 200 epochs
# - Batch size of 256
#
# ## Results
#
# The overall test accuracy achieved is 68%, indicating that the model can correctly identify users based on their eye movements in 68% of cases.
#
# ### Task-Specific Accuracies
#
# 1. Video-viewing task (VID): 93.03%
# 2. Random oblique saccade task (RAN): 72.11%
# 3. Horizontal smooth pursuit task (PUR): 68.33%
# 4. Self-paced reading task (TEX): 57.37%
# 5. Vergence task (VRG): 43.82%
#
# ## Analysis
#
# The results show that different tasks have varying levels of effectiveness in identifying users:
#
# 1. The video-viewing task is the most effective, with an impressive 93.03% accuracy. This suggests that how people watch videos is highly individual and consistent.
#
# 2. The random oblique saccade task and horizontal smooth pursuit task show moderate effectiveness, with accuracies above the overall average.
#
# 3. The self-paced reading task and vergence task are less effective for user identification, with accuracies below the overall average.
#
# These findings indicate that complex, naturalistic tasks like video viewing may be more suitable for eye movement-based user identification compared to simpler, controlled tasks like vergence exercises.
#
# ## Conclusion
#
# This study demonstrates the potential of using eye movement patterns for user identification, with varying degrees of success across different tasks. The use of the Savitzky-Golay filter for velocity calculation provides a robust basis for feature extraction. Future work could focus on optimizing feature extraction for the most effective tasks or combining data from multiple tasks to improve overall accuracy.

# %%
position_columns = ['x_left', 'y_left', 'x_right', 'y_right']

# Calculate velocity
dataset.pos2vel( method='savitzky_golay', degree=2, window_length=7)
print(dataset.gaze[5].frame)
# Out:
#   0%|          | 0/5020 [00:00<?, ?it/s]
# shape: (14_815, 16)
# ┌────────────┬────────────┬───────────┬────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ time       ┆ x_target_p ┆ y_target_ ┆ zT     ┆ … ┆ session_i ┆ task_name ┆ position  ┆ velocity  │
# │ ---        ┆ os         ┆ pos       ┆ ---    ┆   ┆ d         ┆ ---       ┆ ---       ┆ ---       │
# │ f32        ┆ ---        ┆ ---       ┆ f32    ┆   ┆ ---       ┆ str       ┆ list[f32] ┆ list[f32] │
# │            ┆ f32        ┆ f32       ┆        ┆   ┆ i64       ┆           ┆           ┆           │
# ╞════════════╪════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0.0        ┆ 0.0        ┆ 0.0       ┆ 0.4433 ┆ … ┆ 2         ┆ 1_VRG     ┆ [4.9966,  ┆ [5.709814 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.9662, … ┆ , -2.6580 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.7913]   ┆ 34, …     │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ -0.61249… │
# │ 3.9182     ┆ 0.0        ┆ 0.0       ┆ 0.4433 ┆ … ┆ 2         ┆ 1_VRG     ┆ [5.0888,  ┆ [9.157129 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 1.0297, … ┆ ,         │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.7971]   ┆ 1.611607, │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ … -0.5616 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ 07…       │
# │ 7.953      ┆ 0.0        ┆ 0.0       ┆ 0.4433 ┆ … ┆ 2         ┆ 1_VRG     ┆ [5.1924,  ┆ [11.67320 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.794, …  ┆ 8,        │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.7799]   ┆ 1.870536, │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ …         │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ -0.60982… │
# │ 11.9337    ┆ 0.0        ┆ 0.0       ┆ 0.4433 ┆ … ┆ 2         ┆ 1_VRG     ┆ [5.0485,  ┆ [6.837496 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.9606, … ┆ ,         │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.7741]   ┆ 2.630357, │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ … -0.5571 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ 44…       │
# │ …          ┆ …          ┆ …         ┆ …      ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 59247.8281 ┆ 0.0        ┆ 0.0       ┆ 0.3543 ┆ … ┆ 2         ┆ 1_VRG     ┆ [5.8084,  ┆ [-0.88124 │
# │ 25         ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.5356, … ┆ 2, -4.474 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.0859]   ┆ 107, …    │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ 0.30446…  │
# │ 59251.8398 ┆ 0.0        ┆ 0.0       ┆ 0.3543 ┆ … ┆ 2         ┆ 1_VRG     ┆ [5.7045,  ┆ [-0.94017 │
# │ 44         ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.6967, … ┆ 4, -6.738 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.0859]   ┆ 393, …    │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ -0.0526…  │
# │ 59255.8476 ┆ 0.0        ┆ 0.0       ┆ 0.3543 ┆ … ┆ 2         ┆ 1_VRG     ┆ [5.7566,  ┆ [-1.09732 │
# │ 56         ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.4377, … ┆ 6, -7.459 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.0745]   ┆ 822, …    │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ -0.1553…  │
# │ 59259.8593 ┆ 0.0        ┆ 0.0       ┆ 0.3543 ┆ … ┆ 2         ┆ 1_VRG     ┆ [5.7504,  ┆ [-0.78928 │
# │ 75         ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.38, …   ┆ 9, -10.33 │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆ 0.0859]   ┆ 8393, …   │
# │            ┆            ┆           ┆        ┆   ┆           ┆           ┆           ┆ 0.1017…   │
# └────────────┴────────────┴───────────┴────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import numpy as np
from scipy import stats
import polars as pl
from tqdm import tqdm

def extract_features(gaze_data, n_portions=10, set_type='train'):
    features = []
    y = []
    task_names = []

    for gaze in tqdm(gaze_data):
        frame = gaze.frame
        # Create a temporary index column
        frame = frame.with_row_count("temp_index")

        if set_type == 'train':
            frame = frame.filter(pl.col('temp_index') >0)
        elif set_type == 'test':
            frame = frame.filter(pl.col('temp_index') >0)

        # Drop the temporary index column
        frame = frame.drop('temp_index')

        total_samples = frame.shape[0]
        portion_size = total_samples // n_portions

        # Initialize lists to store portion-wise statistics
        portion_features = []

        # Calculate statistics for each portion
        for i in range(n_portions):
            start_idx = i * portion_size
            end_idx = (i + 1) * portion_size if i < n_portions - 1 else total_samples

            portion = frame.slice(start_idx, end_idx - start_idx)

            # Velocity statistics
            velocities = portion['velocity'].apply(lambda x: np.linalg.norm(x)).to_numpy()

            # Position statistics
            positions = np.vstack(portion['position'].to_numpy())

            portion_stats = [
                np.mean(velocities),
                np.std(velocities),
                np.max(velocities),
                *np.mean(positions, axis=0),
                *np.std(positions, axis=0),
                stats.skew(velocities),
                stats.kurtosis(velocities)
            ]

            # Add any other relevant statistics from other columns
            if 'x_target_pos' in portion.columns and 'y_target_pos' in portion.columns:
                portion_stats.extend([
                    portion['x_target_pos'].mean(),
                    portion['y_target_pos'].mean(),
                    portion['x_target_pos'].std(),
                    portion['y_target_pos'].std()
                ])

            portion_features.extend(portion_stats)

        # Global features
        velocities = frame['velocity'].apply(lambda x: np.linalg.norm(x)).to_numpy()
        positions = np.vstack(frame['position'].to_numpy())

        global_features = [
            np.mean(velocities),
            np.std(velocities),
            np.max(velocities),
            *np.mean(positions, axis=0),
            *np.std(positions, axis=0),
            stats.skew(velocities),
            stats.kurtosis(velocities)
        ]

        # Saccade and fixation features
        saccade_threshold = np.mean(velocities) + 2 * np.std(velocities)
        fixation_threshold = np.mean(velocities) - np.std(velocities)
        saccade_rate = np.sum(velocities > saccade_threshold) / total_samples
        fixation_rate = np.sum(velocities < fixation_threshold) / total_samples

        # Task-specific features
        task_name = frame['task_name'][0]
        task_duration = total_samples  # Assuming constant sampling rate

        # Combine all features
        feature_vector = portion_features + global_features + [saccade_rate, fixation_rate, task_duration]

        features.append(feature_vector)
        y.append(frame['subject_id'][0])
        task_names.append(task_name)

    return np.array(features), np.array(y), np.array(task_names)

# Extract features for training set (1st and 2nd rows)
X_train, y_train, task_names_train = extract_features(dataset.gaze, n_portions=200, set_type='train')

# Extract features for test set (every 3rd row)
X_test, y_test, task_names_test = extract_features(dataset.gaze, n_portions=200, set_type='test')

# Save the features
np.save('X_train.npy', X_train)
np.save('y_train.npy', y_train)
np.save('task_names_train.npy', task_names_train)

np.save('X_test.npy', X_test)
np.save('y_test.npy', y_test)
np.save('task_names_test.npy', task_names_test)

print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")
# Out:
#   0%|          | 0/5020 [00:00<?, ?it/s]<ipython-input-5-4954a06d2ee7>:38: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   velocities = portion['velocity'].apply(lambda x: np.linalg.norm(x)).to_numpy()
# <ipython-input-5-4954a06d2ee7>:65: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   velocities = frame['velocity'].apply(lambda x: np.linalg.norm(x)).to_numpy()
#   0%|          | 21/5020 [00:27<1:48:07,  1.30s/it]
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# <ipython-input-5-4954a06d2ee7> in <cell line: 98>()
#      96
#      97 # Extract features for training set (1st and 2nd rows)
# ---> 98 X_train, y_train, task_names_train = extract_features(dataset.gaze, n_portions=200, set_type='train')
#      99
#     100 # Extract features for test set (every 3rd row)
#
# <ipython-input-5-4954a06d2ee7> in extract_features(gaze_data, n_portions, set_type)
#      63
#      64         # Global features
# ---> 65         velocities = frame['velocity'].apply(lambda x: np.linalg.norm(x)).to_numpy()
#      66         positions = np.vstack(frame['position'].to_numpy())
#      67
#
# /usr/local/lib/python3.10/dist-packages/polars/utils/deprecation.py in wrapper(*args, **kwargs)
#      59                 version=version,
#      60             )
# ---> 61             return function(*args, **kwargs)
#      62
#      63         wrapper.__signature__ = inspect.signature(function)  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.10/dist-packages/polars/series/series.py in apply(self, function, return_dtype, skip_nulls)
#    6783
#    6784         """
# -> 6785         return self.map_elements(function, return_dtype, skip_nulls=skip_nulls)
#    6786
#    6787     @deprecate_renamed_function("rolling_map", version="0.19.0")
#
# /usr/local/lib/python3.10/dist-packages/polars/series/series.py in map_elements(self, function, return_dtype, skip_nulls)
#    5030         warn_on_inefficient_map(function, columns=[self.name], map_target="series")
#    5031         return self._from_pyseries(
# -> 5032             self._s.apply_lambda(function, pl_return_dtype, skip_nulls)
#    5033         )
#    5034
#
# PanicException: called `Result::unwrap()` on an `Err` value: PyErr { type: <class 'KeyboardInterrupt'>, value: KeyboardInterrupt(), traceback: Some(<traceback object at 0x7e38c9bb7900>) }

# %%
import os
from collections import defaultdict

import numpy as np
import torch
from sklearn.metrics import accuracy_score
from torch import nn
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from google.colab import drive

class EyeMovementDataset(Dataset):
    def __init__(self, X, y, user_to_index):
        self.X = torch.FloatTensor(X)
        self.y = torch.LongTensor([user_to_index[user] for user in y])

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


class MLPClassifier(nn.Module):
    def __init__(self, input_size, num_classes):
        super(MLPClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc5 = nn.Linear(16, num_classes)
        self.fc6 = nn.Linear(input_size, num_classes)

    def forward(self, x):
        out = torch.relu(self.fc1(x))
        out = torch.relu(self.fc2(out))
        out = self.fc5(out)
        d = self.fc6(x)
        return out + 10 * d


def evaluate_task_accuracy(
    model,
    X_test,
    y_test,
    task_names_test,
    user_to_index,
    index_to_user,
    specific_task=None,
):
    model.eval()
    device = next(model.parameters()).device

    X_test_tensor = torch.FloatTensor(X_test).to(device)
    y_test_tensor = torch.LongTensor([user_to_index[user] for user in y_test]).to(
        device
    )

    with torch.no_grad():
        outputs = model(X_test_tensor)
        probabilities = torch.softmax(outputs, dim=1)
        _, predicted = torch.max(outputs.data, 1)

    predicted = predicted.cpu().numpy()
    probabilities = probabilities.cpu().numpy()

    task_results = defaultdict(lambda: {"true": [], "pred": [], "prob": []})
    for true, pred, prob, task in zip(
        y_test, predicted, probabilities, task_names_test
    ):
        task_results[task]["true"].append(true)
        task_results[task]["pred"].append(index_to_user[pred])
        task_results[task]["prob"].append(prob[user_to_index[true]])

    task_accuracies = {}
    for task, results in task_results.items():
        if specific_task is None or task == specific_task:
            accuracy = accuracy_score(results["true"], results["pred"])
            avg_probability = np.mean(results["prob"])
            task_accuracies[task] = {
                "accuracy": accuracy,
                "avg_probability": avg_probability,
            }

    if specific_task:
        if specific_task in task_accuracies:
            print(f"Task: {specific_task}")
            # print(f"Accuracy: {task_accuracies[specific_task]['accuracy']:.2%}")
            # print(
            #     f"Average Probability: {task_accuracies[specific_task]['avg_probability']:.4f}"
            # )
        else:
            print(f"Task {specific_task} not found in the test set.")
    else:
        sorted_tasks = sorted(
            task_accuracies.items(), key=lambda x: x[1]["accuracy"], reverse=True
        )
        print("Task Accuracies and Average Probabilities:")
        for task, metrics in sorted_tasks:
            print(
                f"{task}: Accuracy: {metrics['accuracy']:.2%}, Avg Probability: {metrics['avg_probability']:.4f}"
            )

    return task_accuracies

# Mount Google Drive
drive.mount('/content/drive')

# Set the working directory to your Google Drive folder
working_dir = '/content/drive/My Drive'  # Change this to your actual folder path
os.chdir(working_dir)

# Load the data
X_train = np.load("X_train.npy", allow_pickle=True).astype(np.float32)
y_train = np.load("y_train.npy", allow_pickle=True)
X_test = np.load("X_test.npy", allow_pickle=True).astype(np.float32)
y_test = np.load("y_test.npy", allow_pickle=True)
task_names_test = np.load("task_names_test.npy", allow_pickle=True)

# Get unique task names
unique_task_names = np.unique(task_names_test)
# print("Available tasks:", unique_task_names)

# Create user ID to index mapping
unique_users = np.unique(np.concatenate([y_train, y_test]))
user_to_index = {user: idx for idx, user in enumerate(unique_users)}
index_to_user = {idx: user for user, idx in user_to_index.items()}

# Check for NaN or infinite values
X_train = np.nan_to_num(X_train, nan=0, posinf=1e6, neginf=-1e6)
X_test = np.nan_to_num(X_test, nan=0, posinf=1e6, neginf=-1e6)

# Initialize model
input_size = X_train.shape[1]
num_classes = len(unique_users)
model = MLPClassifier(input_size, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Check if a trained model exists
model_path = "model.pth"
if os.path.exists(model_path):
    print("Loading existing model...")
    model.load_state_dict(torch.load(model_path))
else:
    print("Training new model...")
    # Create datasets and dataloaders
    train_dataset = EyeMovementDataset(X_train, y_train, user_to_index)
    train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.05)

    # Training loop
    num_epochs = 200

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for batch_X, batch_y in tqdm(
            train_dataloader, desc=f"Epoch {epoch+1}/{num_epochs}"
        ):
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(
            f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_dataloader):.4f}"
        )

    # Save the model
    torch.save(model.state_dict(), model_path)

# Evaluation on test set
model.eval()
test_dataset = EyeMovementDataset(X_test, y_test, user_to_index)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

with torch.no_grad():
    correct = 0
    total = 0
    for batch_X, batch_y in test_dataloader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        outputs = model(batch_X)
        _, predicted = torch.max(outputs.data, 1)
        total += batch_y.size(0)
        correct += (predicted == batch_y).sum().item()
        # print predicted user vs true user
        print(predicted[1], batch_y[1])

    print(f"Overall Test Accuracy: {100 * correct / total:.2f}%")

chosen_task = "3_VID"
task_accuracies = evaluate_task_accuracy(
    model, X_test, y_test, task_names_test, user_to_index, index_to_user, chosen_task
)


def predict_user_data(model, test_dataloader, indexes, index_to_user, device):
    model.eval()
    all_predictions = []
    all_true_labels = []

    with torch.no_grad():
        for i, (batch_X, batch_y) in enumerate(test_dataloader):
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            outputs = model(batch_X)
            _, predicted = torch.max(outputs.data, 1)

            for j, idx in enumerate(
                range(
                    i * test_dataloader.batch_size, (i + 1) * test_dataloader.batch_size
                )
            ):
                if idx in indexes:
                    pred_user = index_to_user[predicted[j].item()]
                    true_user = index_to_user[batch_y[j].item()]
                    all_predictions.append(pred_user)
                    all_true_labels.append(true_user)
                    print(
                        f"Sample {idx}: Predicted User: {pred_user}, True User: {true_user}"
                    )

    return all_predictions, all_true_labels


# Usage example:
indexes_to_predict = [0, 13, 61, 72, 13, 15, 18, 20, 95, 129, 130, 140, 241, 242, 236, 347]  # Example indexes
predictions, true_labels = predict_user_data(
    model, test_dataloader, indexes_to_predict, index_to_user, device
)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-6ecde13ae0d5> in <cell line: 105>()
#     103
#     104 # Mount Google Drive
# --> 105 drive.mount('/content/drive')
#     106
#     107 # Set the working directory to your Google Drive folder
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# Evaluation on test set
model.eval()
test_dataset = EyeMovementDataset(X_test, y_test, user_to_index)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

with torch.no_grad():
    correct = 0
    total = 0
    for batch_X, batch_y in test_dataloader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        outputs = model(batch_X)
        _, predicted = torch.max(outputs.data, 1)
        total += batch_y.size(0)
        correct += (predicted == batch_y).sum().item()
        # print predicted user vs true user
        print(predicted[1], batch_y[1])

    print(f"Overall Test Accuracy: {100 * correct / total:.2f}%")

chosen_task = "3_VID"
task_accuracies = evaluate_task_accuracy(
    model, X_test, y_test, task_names_test, user_to_index, index_to_user, chosen_task
)


def predict_user_data(model, test_dataloader, indexes, index_to_user, device):
    model.eval()
    all_predictions = []
    all_true_labels = []

    with torch.no_grad():
        for i, (batch_X, batch_y) in enumerate(test_dataloader):
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            outputs = model(batch_X)
            _, predicted = torch.max(outputs.data, 1)

            for j, idx in enumerate(
                range(
                    i * test_dataloader.batch_size, (i + 1) * test_dataloader.batch_size
                )
            ):
                if idx in indexes:
                    pred_user = index_to_user[predicted[j].item()]
                    true_user = index_to_user[batch_y[j].item()]
                    all_predictions.append(pred_user)
                    all_true_labels.append(true_user)
                    print(
                        f"Sample {idx}: Predicted User: {pred_user}, True User: {true_user}"
                    )

    return all_predictions, all_true_labels


# Usage example:
indexes_to_predict = [0, 13, 61, 72, 13, 15, 18, 20, 95, 129, 130, 140, 241, 242, 236, 347]  # Example indexes
predictions, true_labels = predict_user_data(
    model, test_dataloader, indexes_to_predict, index_to_user, device
)
# Out:
# tensor(0) tensor(0)
# tensor(3) tensor(3)
# tensor(6) tensor(6)
# tensor(9) tensor(9)
# tensor(12) tensor(12)
# tensor(16) tensor(16)
# tensor(19) tensor(19)
# tensor(22) tensor(22)
# tensor(25) tensor(25)
# tensor(28) tensor(28)
# tensor(32) tensor(32)
# tensor(35) tensor(35)
# tensor(38) tensor(38)
# tensor(41) tensor(41)
# tensor(44) tensor(44)
# tensor(48) tensor(48)
# tensor(51) tensor(51)
# tensor(54) tensor(54)
# tensor(57) tensor(57)
# tensor(60) tensor(60)
# tensor(64) tensor(64)
# tensor(67) tensor(67)
# tensor(70) tensor(70)
# tensor(73) tensor(73)
# tensor(76) tensor(76)
# tensor(80) tensor(80)
# tensor(83) tensor(83)
# tensor(86) tensor(86)
# tensor(89) tensor(89)
# tensor(92) tensor(92)
# tensor(96) tensor(96)
# tensor(99) tensor(99)
# tensor(102) tensor(102)
# tensor(105) tensor(105)
# tensor(108) tensor(108)
# tensor(112) tensor(112)
# tensor(115) tensor(115)
# tensor(118) tensor(118)
# tensor(121) tensor(121)
# tensor(124) tensor(124)
# tensor(128) tensor(128)
# tensor(131) tensor(131)
# tensor(134) tensor(134)
# tensor(137) tensor(137)
# tensor(140) tensor(140)
# tensor(144) tensor(144)
# tensor(147) tensor(147)
# tensor(150) tensor(150)
# tensor(153) tensor(153)
# tensor(156) tensor(156)
# tensor(160) tensor(160)
# tensor(163) tensor(163)
# tensor(166) tensor(166)
# tensor(169) tensor(169)
# tensor(172) tensor(172)
# tensor(176) tensor(176)
# tensor(179) tensor(179)
# tensor(182) tensor(182)
# tensor(185) tensor(185)
# tensor(188) tensor(188)
# tensor(192) tensor(192)
# tensor(195) tensor(195)
# tensor(198) tensor(198)
# tensor(201) tensor(201)
# tensor(204) tensor(204)
# tensor(208) tensor(208)
# tensor(211) tensor(211)
# tensor(214) tensor(214)
# tensor(217) tensor(217)
# tensor(220) tensor(220)
# tensor(224) tensor(224)
# tensor(227) tensor(227)
# tensor(230) tensor(230)
# tensor(233) tensor(233)
# tensor(236) tensor(236)
# tensor(240) tensor(240)
# tensor(243) tensor(243)
# tensor(246) tensor(246)
# tensor(249) tensor(249)
# tensor(252) tensor(252)
# tensor(256) tensor(256)
# tensor(259) tensor(259)
# tensor(262) tensor(262)
# tensor(265) tensor(265)
# tensor(268) tensor(268)
# tensor(272) tensor(272)
# tensor(275) tensor(275)
# tensor(278) tensor(278)
# tensor(281) tensor(281)
# tensor(284) tensor(284)
# tensor(288) tensor(288)
# tensor(291) tensor(291)
# tensor(294) tensor(294)
# tensor(297) tensor(297)
# tensor(300) tensor(300)
# tensor(304) tensor(304)
# tensor(307) tensor(307)
# tensor(310) tensor(310)
# tensor(313) tensor(313)
# tensor(316) tensor(316)
# tensor(320) tensor(320)
# tensor(323) tensor(323)
# tensor(326) tensor(326)
# tensor(329) tensor(329)
# tensor(332) tensor(332)
# tensor(336) tensor(336)
# tensor(339) tensor(339)
# tensor(342) tensor(342)
# tensor(345) tensor(345)
# tensor(348) tensor(348)
# tensor(352) tensor(352)
# tensor(355) tensor(355)
# tensor(358) tensor(358)
# tensor(361) tensor(361)
# tensor(364) tensor(364)
# tensor(368) tensor(368)
# tensor(371) tensor(371)
# tensor(374) tensor(374)
# tensor(377) tensor(377)
# tensor(380) tensor(380)
# tensor(384) tensor(384)
# tensor(387) tensor(387)
# tensor(390) tensor(390)
# tensor(393) tensor(393)
# tensor(396) tensor(396)
# tensor(400) tensor(400)
# tensor(403) tensor(403)
# tensor(406) tensor(406)
# tensor(10) tensor(10)
# tensor(21) tensor(21)
# tensor(87) tensor(87)
# tensor(104) tensor(104)
# tensor(122) tensor(122)
# tensor(148) tensor(148)
# tensor(154) tensor(154)
# tensor(194) tensor(194)
# tensor(221) tensor(221)
# tensor(243) tensor(243)
# tensor(273) tensor(273)
# tensor(46) tensor(46)
# tensor(76) tensor(76)
# tensor(84) tensor(84)
# tensor(130) tensor(130)
# tensor(152) tensor(152)
# tensor(177) tensor(177)
# tensor(197) tensor(197)
# tensor(214) tensor(214)
# tensor(232) tensor(232)
# tensor(243) tensor(249)
# tensor(259) tensor(259)
# tensor(277) tensor(277)
# tensor(293) tensor(293)
# tensor(308) tensor(308)
# tensor(320) tensor(320)
# tensor(335) tensor(335)
# tensor(369) tensor(369)
# tensor(386) tensor(386)
# Overall Test Accuracy: 98.59%
# Task: 3_VID
# Sample 0: Predicted User: 2, True User: 2
# Sample 13: Predicted User: 3, True User: 3
# Sample 15: Predicted User: 3, True User: 3
# Sample 18: Predicted User: 3, True User: 3
# Sample 20: Predicted User: 4, True User: 4
# Sample 61: Predicted User: 8, True User: 8
# Sample 72: Predicted User: 9, True User: 9
# Sample 95: Predicted User: 11, True User: 11
# Sample 129: Predicted User: 14, True User: 14
# Sample 130: Predicted User: 15, True User: 15
# Sample 140: Predicted User: 16, True User: 16
# Sample 236: Predicted User: 25, True User: 25
# Sample 241: Predicted User: 26, True User: 26
# Sample 242: Predicted User: 26, True User: 26
# Sample 347: Predicted User: 37, True User: 37

# %%
# Usage example:
indexes_to_predict = [5000]  # Example indexes
predictions, true_labels = predict_user_data(
    model, test_dataloader, indexes_to_predict, index_to_user, device
)
# Out:
# Sample 4000: Predicted User: 455, True User: 455

# %%
# Assuming you have a list of all possible user indices from 1 to 200,000
all_user_indices = list(range(1, 200001))  # This includes all users from 1 to 200,000

# Run the prediction on all these indices
predictions, true_labels = predict_user_data(
    model, test_dataloader, all_user_indices, index_to_user, device
)

# Print the results
for i, (pred, true) in enumerate(zip(predictions, true_labels)):
    print(f"Sample {all_user_indices[i]}: Predicted User: {pred}, True User: {true}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Sample 20: Predicted User: 4, True User: 4
# Sample 21: Predicted User: 4, True User: 4
# Sample 22: Predicted User: 4, True User: 4
# Sample 23: Predicted User: 4, True User: 4
# Sample 24: Predicted User: 4, True User: 4
# Sample 25: Predicted User: 4, True User: 4
# Sample 26: Predicted User: 4, True User: 4
# Sample 27: Predicted User: 4, True User: 4
# Sample 28: Predicted User: 4, True User: 4
# Sample 29: Predicted User: 4, True User: 4
# Sample 30: Predicted User: 5, True User: 5
# Sample 31: Predicted User: 5, True User: 5
# Sample 32: Predicted User: 5, True User: 5
# Sample 33: Predicted User: 5, True User: 5
# Sample 34: Predicted User: 5, True User: 5
# Sample 35: Predicted User: 5, True User: 5
# Sample 36: Predicted User: 5, True User: 5
# Sample 37: Predicted User: 5, True User: 5
# Sample 38: Predicted User: 5, True User: 5
# Sample 39: Predicted User: 5, True User: 5
# Sample 40: Predicted User: 6, True User: 6
# Sample 41: Predicted User: 6, True User: 6
# Sample 42: Predicted User: 6, True User: 6
# Sample 43: Predicted User: 6, True User: 6
# Sample 44: Predicted User: 6, True User: 6
# Sample 45: Predicted User: 6, True User: 6
# Sample 46: Predicted User: 6, True User: 6
# Sample 47: Predicted User: 6, True User: 6
# Sample 48: Predicted User: 6, True User: 6
# Sample 49: Predicted User: 6, True User: 6
# Sample 50: Predicted User: 7, True User: 7
# Sample 51: Predicted User: 7, True User: 7
# Sample 52: Predicted User: 7, True User: 7
# Sample 53: Predicted User: 7, True User: 7
# Sample 54: Predicted User: 7, True User: 7
# Sample 55: Predicted User: 7, True User: 7
# Sample 56: Predicted User: 7, True User: 7
# Sample 57: Predicted User: 7, True User: 7
# Sample 58: Predicted User: 7, True User: 7
# Sample 59: Predicted User: 7, True User: 7
# Sample 60: Predicted User: 8, True User: 8
# Sample 61: Predicted User: 8, True User: 8
# Sample 62: Predicted User: 8, True User: 8
# Sample 63: Predicted User: 8, True User: 8
# Sample 64: Predicted User: 8, True User: 8
# Sample 65: Predicted User: 8, True User: 8
# Sample 66: Predicted User: 8, True User: 8
# Sample 67: Predicted User: 8, True User: 8
# Sample 68: Predicted User: 8, True User: 8
# Sample 69: Predicted User: 8, True User: 8
# Sample 70: Predicted User: 9, True User: 9
# Sample 71: Predicted User: 9, True User: 9
# Sample 72: Predicted User: 9, True User: 9
# Sample 73: Predicted User: 9, True User: 9
# Sample 74: Predicted User: 9, True User: 9
# Sample 75: Predicted User: 9, True User: 9
# Sample 76: Predicted User: 9, True User: 9
# Sample 77: Predicted User: 9, True User: 9
# Sample 78: Predicted User: 9, True User: 9
# Sample 79: Predicted User: 9, True User: 9
# Sample 80: Predicted User: 10, True User: 10
# Sample 81: Predicted User: 10, True User: 10
# Sample 82: Predicted User: 10, True User: 10
# Sample 83: Predicted User: 10, True User: 10
# Sample 84: Predicted User: 10, True User: 10
# Sample 85: Predicted User: 10, True User: 10
# Sample 86: Predicted User: 10, True User: 10
# Sample 87: Predicted User: 10, True User: 10
# Sample 88: Predicted User: 10, True User: 10
# Sample 89: Predicted User: 10, True User: 10
# Sample 90: Predicted User: 11, True User: 11
# Sample 91: Predicted User: 11, True User: 11
# Sample 92: Predicted User: 11, True User: 11
# Sample 93: Predicted User: 11, True User: 11
# Sample 94: Predicted User: 11, True User: 11
# Sample 95: Predicted User: 11, True User: 11
# Sample 96: Predicted User: 11, True User: 11
# Sample 97: Predicted User: 11, True User: 11
# Sample 98: Predicted User: 11, True User: 11
# Sample 99: Predicted User: 11, True User: 11
# Sample 100: Predicted User: 425, True User: 12
# Sample 101: Predicted User: 271, True User: 12
# Sample 102: Predicted User: 12, True User: 12
# Sample 103: Predicted User: 12, True User: 12
# Sample 104: Predicted User: 12, True User: 12
# Sample 105: Predicted User: 118, True User: 12
# Sample 106: Predicted User: 271, True User: 12
# Sample 107: Predicted User: 12, True User: 12
# Sample 108: Predicted User: 12, True User: 12
# Sample 109: Predicted User: 12, True User: 12
# Sample 110: Predicted User: 13, True User: 13
# Sample 111: Predicted User: 13, True User: 13
# Sample 112: Predicted User: 13, True User: 13
# Sample 113: Predicted User: 13, True User: 13
# Sample 114: Predicted User: 13, True User: 13
# Sample 115: Predicted User: 13, True User: 13
# Sample 116: Predicted User: 13, True User: 13
# Sample 117: Predicted User: 13, True User: 13
# Sample 118: Predicted User: 13, True User: 13
# Sample 119: Predicted User: 13, True User: 13
# Sample 120: Predicted User: 14, True User: 14
# Sample 121: Predicted User: 14, True User: 14
# Sample 122: Predicted User: 14, True User: 14
# Sample 123: Predicted User: 14, True User: 14
# Sample 124: Predicted User: 14, True User: 14
# Sample 125: Predicted User: 14, True User: 14
# Sample 126: Predicted User: 14, True User: 14
# Sample 127: Predicted User: 14, True User: 14
# Sample 128: Predicted User: 14, True User: 14
# Sample 129: Predicted User: 14, True User: 14
# Sample 130: Predicted User: 15, True User: 15
# Sample 131: Predicted User: 15, True User: 15
# Sample 132: Predicted User: 15, True User: 15
# Sample 133: Predicted User: 15, True User: 15
# Sample 134: Predicted User: 15, True User: 15
# Sample 135: Predicted User: 15, True User: 15
# Sample 136: Predicted User: 15, True User: 15
# Sample 137: Predicted User: 15, True User: 15
# Sample 138: Predicted User: 15, True User: 15
# Sample 139: Predicted User: 15, True User: 15
# Sample 140: Predicted User: 16, True User: 16
# Sample 141: Predicted User: 16, True User: 16
# Sample 142: Predicted User: 16, True User: 16
# Sample 143: Predicted User: 16, True User: 16
# Sample 144: Predicted User: 16, True User: 16
# Sample 145: Predicted User: 16, True User: 16
# Sample 146: Predicted User: 16, True User: 16
# Sample 147: Predicted User: 16, True User: 16
# Sample 148: Predicted User: 16, True User: 16
# Sample 149: Predicted User: 16, True User: 16
# Sample 150: Predicted User: 17, True User: 17
# Sample 151: Predicted User: 17, True User: 17
# Sample 152: Predicted User: 17, True User: 17
# Sample 153: Predicted User: 17, True User: 17
# Sample 154: Predicted User: 17, True User: 17
# Sample 155: Predicted User: 17, True User: 17
# Sample 156: Predicted User: 17, True User: 17
# Sample 157: Predicted User: 17, True User: 17
# Sample 158: Predicted User: 17, True User: 17
# Sample 159: Predicted User: 17, True User: 17
# Sample 160: Predicted User: 18, True User: 18
# Sample 161: Predicted User: 18, True User: 18
# Sample 162: Predicted User: 18, True User: 18
# Sample 163: Predicted User: 18, True User: 18
# Sample 164: Predicted User: 18, True User: 18
# Sample 165: Predicted User: 18, True User: 18
# Sample 166: Predicted User: 18, True User: 18
# Sample 167: Predicted User: 18, True User: 18
# Sample 168: Predicted User: 18, True User: 18
# Sample 169: Predicted User: 18, True User: 18
# Sample 170: Predicted User: 19, True User: 19
# Sample 171: Predicted User: 19, True User: 19
# Sample 172: Predicted User: 19, True User: 19
# Sample 173: Predicted User: 19, True User: 19
# Sample 174: Predicted User: 19, True User: 19
# Sample 175: Predicted User: 19, True User: 19
# Sample 176: Predicted User: 19, True User: 19
# Sample 177: Predicted User: 19, True User: 19
# Sample 178: Predicted User: 19, True User: 19
# Sample 179: Predicted User: 19, True User: 19
# Sample 180: Predicted User: 20, True User: 20
# Sample 181: Predicted User: 20, True User: 20
# Sample 182: Predicted User: 20, True User: 20
# Sample 183: Predicted User: 20, True User: 20
# Sample 184: Predicted User: 20, True User: 20
# Sample 185: Predicted User: 20, True User: 20
# Sample 186: Predicted User: 20, True User: 20
# Sample 187: Predicted User: 20, True User: 20
# Sample 188: Predicted User: 20, True User: 20
# Sample 189: Predicted User: 20, True User: 20
# Sample 190: Predicted User: 21, True User: 21
# Sample 191: Predicted User: 21, True User: 21
# Sample 192: Predicted User: 21, True User: 21
# Sample 193: Predicted User: 21, True User: 21
# Sample 194: Predicted User: 21, True User: 21
# Sample 195: Predicted User: 21, True User: 21
# Sample 196: Predicted User: 21, True User: 21
# Sample 197: Predicted User: 21, True User: 21
# Sample 198: Predicted User: 21, True User: 21
# Sample 199: Predicted User: 21, True User: 21
# Sample 200: Predicted User: 22, True User: 22
# Sample 201: Predicted User: 22, True User: 22
# Sample 202: Predicted User: 22, True User: 22
# Sample 203: Predicted User: 22, True User: 22
# Sample 204: Predicted User: 22, True User: 22
# Sample 205: Predicted User: 22, True User: 22
# Sample 206: Predicted User: 22, True User: 22
# Sample 207: Predicted User: 22, True User: 22
# Sample 208: Predicted User: 22, True User: 22
# Sample 209: Predicted User: 22, True User: 22
# Sample 210: Predicted User: 23, True User: 23
# Sample 211: Predicted User: 23, True User: 23
# Sample 212: Predicted User: 23, True User: 23
# Sample 213: Predicted User: 23, True User: 23
# Sample 214: Predicted User: 23, True User: 23
# Sample 215: Predicted User: 23, True User: 23
# Sample 216: Predicted User: 23, True User: 23
# Sample 217: Predicted User: 23, True User: 23
# Sample 218: Predicted User: 23, True User: 23
# Sample 219: Predicted User: 23, True User: 23
# Sample 220: Predicted User: 24, True User: 24
# Sample 221: Predicted User: 24, True User: 24
# Sample 222: Predicted User: 24, True User: 24
# Sample 223: Predicted User: 24, True User: 24
# Sample 224: Predicted User: 24, True User: 24
# Sample 225: Predicted User: 24, True User: 24
# Sample 226: Predicted User: 24, True User: 24
# Sample 227: Predicted User: 24, True User: 24
# Sample 228: Predicted User: 24, True User: 24
# Sample 229: Predicted User: 24, True User: 24
# Sample 230: Predicted User: 25, True User: 25
# Sample 231: Predicted User: 25, True User: 25
# Sample 232: Predicted User: 25, True User: 25
# Sample 233: Predicted User: 25, True User: 25
# Sample 234: Predicted User: 25, True User: 25
# Sample 235: Predicted User: 25, True User: 25
# Sample 236: Predicted User: 25, True User: 25
# Sample 237: Predicted User: 25, True User: 25
# Sample 238: Predicted User: 25, True User: 25
# Sample 239: Predicted User: 25, True User: 25
# Sample 240: Predicted User: 26, True User: 26
# Sample 241: Predicted User: 26, True User: 26
# Sample 242: Predicted User: 26, True User: 26
# Sample 243: Predicted User: 26, True User: 26
# Sample 244: Predicted User: 26, True User: 26
# Sample 245: Predicted User: 26, True User: 26
# Sample 246: Predicted User: 26, True User: 26
# Sample 247: Predicted User: 26, True User: 26
# Sample 248: Predicted User: 26, True User: 26
# Sample 249: Predicted User: 26, True User: 26
# Sample 250: Predicted User: 27, True User: 27
# Sample 251: Predicted User: 27, True User: 27
# Sample 252: Predicted User: 27, True User: 27
# Sample 253: Predicted User: 27, True User: 27
# Sample 254: Predicted User: 27, True User: 27
# Sample 255: Predicted User: 27, True User: 27
# Sample 256: Predicted User: 27, True User: 27
# Sample 257: Predicted User: 27, True User: 27
# Sample 258: Predicted User: 27, True User: 27
# Sample 259: Predicted User: 27, True User: 27
# Sample 260: Predicted User: 28, True User: 28
# Sample 261: Predicted User: 28, True User: 28
# Sample 262: Predicted User: 28, True User: 28
# Sample 263: Predicted User: 28, True User: 28
# Sample 264: Predicted User: 28, True User: 28
# Sample 265: Predicted User: 28, True User: 28
# Sample 266: Predicted User: 28, True User: 28
# Sample 267: Predicted User: 28, True User: 28
# Sample 268: Predicted User: 28, True User: 28
# Sample 269: Predicted User: 28, True User: 28
# Sample 270: Predicted User: 29, True User: 29
# Sample 271: Predicted User: 29, True User: 29
# Sample 272: Predicted User: 29, True User: 29
# Sample 273: Predicted User: 29, True User: 29
# Sample 274: Predicted User: 29, True User: 29
# Sample 275: Predicted User: 29, True User: 29
# Sample 276: Predicted User: 29, True User: 29
# Sample 277: Predicted User: 29, True User: 29
# Sample 278: Predicted User: 29, True User: 29
# Sample 279: Predicted User: 29, True User: 29
# Sample 280: Predicted User: 30, True User: 30
# Sample 281: Predicted User: 30, True User: 30
# Sample 282: Predicted User: 30, True User: 30
# Sample 283: Predicted User: 30, True User: 30
# Sample 284: Predicted User: 30, True User: 30
# Sample 285: Predicted User: 30, True User: 30
# Sample 286: Predicted User: 30, True User: 30
# Sample 287: Predicted User: 30, True User: 30
# Sample 288: Predicted User: 30, True User: 30
# Sample 289: Predicted User: 30, True User: 30
# Sample 290: Predicted User: 31, True User: 31
# Sample 291: Predicted User: 31, True User: 31
# Sample 292: Predicted User: 31, True User: 31
# Sample 293: Predicted User: 31, True User: 31
# Sample 294: Predicted User: 31, True User: 31
# Sample 295: Predicted User: 31, True User: 31
# Sample 296: Predicted User: 31, True User: 31
# Sample 297: Predicted User: 31, True User: 31
# Sample 298: Predicted User: 31, True User: 31
# Sample 299: Predicted User: 31, True User: 31
# Sample 300: Predicted User: 271, True User: 32
# Sample 301: Predicted User: 177, True User: 32
# Sample 302: Predicted User: 32, True User: 32
# Sample 303: Predicted User: 32, True User: 32
# Sample 304: Predicted User: 32, True User: 32
# Sample 305: Predicted User: 333, True User: 32
# Sample 306: Predicted User: 357, True User: 32
# Sample 307: Predicted User: 32, True User: 32
# Sample 308: Predicted User: 32, True User: 32
# Sample 309: Predicted User: 177, True User: 32
# Sample 310: Predicted User: 33, True User: 33
# Sample 311: Predicted User: 33, True User: 33
# Sample 312: Predicted User: 33, True User: 33
# Sample 313: Predicted User: 33, True User: 33
# Sample 314: Predicted User: 33, True User: 33
# Sample 315: Predicted User: 33, True User: 33
# Sample 316: Predicted User: 33, True User: 33
# Sample 317: Predicted User: 33, True User: 33
# Sample 318: Predicted User: 33, True User: 33
# Sample 319: Predicted User: 33, True User: 33
# Sample 320: Predicted User: 35, True User: 35
# Sample 321: Predicted User: 35, True User: 35
# Sample 322: Predicted User: 35, True User: 35
# Sample 323: Predicted User: 35, True User: 35
# Sample 324: Predicted User: 35, True User: 35
# Sample 325: Predicted User: 35, True User: 35
# Sample 326: Predicted User: 35, True User: 35
# Sample 327: Predicted User: 35, True User: 35
# Sample 328: Predicted User: 35, True User: 35
# Sample 329: Predicted User: 35, True User: 35
# Sample 330: Predicted User: 36, True User: 36
# Sample 331: Predicted User: 36, True User: 36
# Sample 332: Predicted User: 36, True User: 36
# Sample 333: Predicted User: 36, True User: 36
# Sample 334: Predicted User: 36, True User: 36
# Sample 335: Predicted User: 36, True User: 36
# Sample 336: Predicted User: 36, True User: 36
# Sample 337: Predicted User: 36, True User: 36
# Sample 338: Predicted User: 36, True User: 36
# Sample 339: Predicted User: 36, True User: 36
# Sample 340: Predicted User: 37, True User: 37
# Sample 341: Predicted User: 37, True User: 37
# Sample 342: Predicted User: 37, True User: 37
# Sample 343: Predicted User: 37, True User: 37
# Sample 344: Predicted User: 37, True User: 37
# Sample 345: Predicted User: 37, True User: 37
# Sample 346: Predicted User: 37, True User: 37
# Sample 347: Predicted User: 37, True User: 37
# Sample 348: Predicted User: 37, True User: 37
# Sample 349: Predicted User: 37, True User: 37
# Sample 350: Predicted User: 38, True User: 38
# Sample 351: Predicted User: 38, True User: 38
# Sample 352: Predicted User: 38, True User: 38
# Sample 353: Predicted User: 38, True User: 38
# Sample 354: Predicted User: 38, True User: 38
# Sample 355: Predicted User: 38, True User: 38
# Sample 356: Predicted User: 38, True User: 38
# Sample 357: Predicted User: 38, True User: 38
# Sample 358: Predicted User: 38, True User: 38
# Sample 359: Predicted User: 38, True User: 38
# Sample 360: Predicted User: 39, True User: 39
# Sample 361: Predicted User: 39, True User: 39
# Sample 362: Predicted User: 39, True User: 39
# Sample 363: Predicted User: 39, True User: 39
# Sample 364: Predicted User: 39, True User: 39
# Sample 365: Predicted User: 39, True User: 39
# Sample 366: Predicted User: 39, True User: 39
# Sample 367: Predicted User: 39, True User: 39
# Sample 368: Predicted User: 39, True User: 39
# Sample 369: Predicted User: 39, True User: 39
# Sample 370: Predicted User: 40, True User: 40
# Sample 371: Predicted User: 40, True User: 40
# Sample 372: Predicted User: 40, True User: 40
# Sample 373: Predicted User: 40, True User: 40
# Sample 374: Predicted User: 40, True User: 40
# Sample 375: Predicted User: 40, True User: 40
# Sample 376: Predicted User: 40, True User: 40
# Sample 377: Predicted User: 40, True User: 40
# Sample 378: Predicted User: 40, True User: 40
# Sample 379: Predicted User: 40, True User: 40
# Sample 380: Predicted User: 41, True User: 41
# Sample 381: Predicted User: 41, True User: 41
# Sample 382: Predicted User: 41, True User: 41
# Sample 383: Predicted User: 41, True User: 41
# Sample 384: Predicted User: 41, True User: 41
# Sample 385: Predicted User: 41, True User: 41
# Sample 386: Predicted User: 41, True User: 41
# Sample 387: Predicted User: 41, True User: 41
# Sample 388: Predicted User: 41, True User: 41
# Sample 389: Predicted User: 41, True User: 41
# Sample 390: Predicted User: 42, True User: 42
# Sample 391: Predicted User: 42, True User: 42
# Sample 392: Predicted User: 42, True User: 42
# Sample 393: Predicted User: 42, True User: 42
# Sample 394: Predicted User: 42, True User: 42
# Sample 395: Predicted User: 42, True User: 42
# Sample 396: Predicted User: 42, True User: 42
# Sample 397: Predicted User: 42, True User: 42
# Sample 398: Predicted User: 42, True User: 42
# Sample 399: Predicted User: 42, True User: 42
# Sample 400: Predicted User: 43, True User: 43
# Sample 401: Predicted User: 43, True User: 43
# Sample 402: Predicted User: 43, True User: 43
# Sample 403: Predicted User: 43, True User: 43
# Sample 404: Predicted User: 43, True User: 43
# Sample 405: Predicted User: 43, True User: 43
# Sample 406: Predicted User: 43, True User: 43
# Sample 407: Predicted User: 43, True User: 43
# Sample 408: Predicted User: 43, True User: 43
# Sample 409: Predicted User: 43, True User: 43
# Sample 410: Predicted User: 44, True User: 44
# Sample 411: Predicted User: 44, True User: 44
# Sample 412: Predicted User: 44, True User: 44
# Sample 413: Predicted User: 44, True User: 44
# Sample 414: Predicted User: 44, True User: 44
# Sample 415: Predicted User: 44, True User: 44
# Sample 416: Predicted User: 44, True User: 44
# Sample 417: Predicted User: 44, True User: 44
# Sample 418: Predicted User: 44, True User: 44
# Sample 419: Predicted User: 44, True User: 44
# Sample 420: Predicted User: 45, True User: 45
# Sample 421: Predicted User: 45, True User: 45
# Sample 422: Predicted User: 45, True User: 45
# Sample 423: Predicted User: 45, True User: 45
# Sample 424: Predicted User: 45, True User: 45
# Sample 425: Predicted User: 45, True User: 45
# Sample 426: Predicted User: 45, True User: 45
# Sample 427: Predicted User: 45, True User: 45
# Sample 428: Predicted User: 45, True User: 45
# Sample 429: Predicted User: 45, True User: 45
# Sample 430: Predicted User: 47, True User: 47
# Sample 431: Predicted User: 47, True User: 47
# Sample 432: Predicted User: 47, True User: 47
# Sample 433: Predicted User: 47, True User: 47
# Sample 434: Predicted User: 47, True User: 47
# Sample 435: Predicted User: 47, True User: 47
# Sample 436: Predicted User: 47, True User: 47
# Sample 437: Predicted User: 47, True User: 47
# Sample 438: Predicted User: 47, True User: 47
# Sample 439: Predicted User: 47, True User: 47
# Sample 440: Predicted User: 48, True User: 48
# Sample 441: Predicted User: 48, True User: 48
# Sample 442: Predicted User: 48, True User: 48
# Sample 443: Predicted User: 48, True User: 48
# Sample 444: Predicted User: 48, True User: 48
# Sample 445: Predicted User: 48, True User: 48
# Sample 446: Predicted User: 48, True User: 48
# Sample 447: Predicted User: 48, True User: 48
# Sample 448: Predicted User: 48, True User: 48
# Sample 449: Predicted User: 48, True User: 48
# Sample 450: Predicted User: 49, True User: 49
# Sample 451: Predicted User: 49, True User: 49
# Sample 452: Predicted User: 49, True User: 49
# Sample 453: Predicted User: 49, True User: 49
# Sample 454: Predicted User: 49, True User: 49
# Sample 455: Predicted User: 49, True User: 49
# Sample 456: Predicted User: 49, True User: 49
# Sample 457: Predicted User: 49, True User: 49
# Sample 458: Predicted User: 49, True User: 49
# Sample 459: Predicted User: 49, True User: 49
# Sample 460: Predicted User: 425, True User: 51
# Sample 461: Predicted User: 51, True User: 51
# Sample 462: Predicted User: 51, True User: 51
# Sample 463: Predicted User: 51, True User: 51
# Sample 464: Predicted User: 51, True User: 51
# Sample 465: Predicted User: 51, True User: 51
# Sample 466: Predicted User: 51, True User: 51
# Sample 467: Predicted User: 51, True User: 51
# Sample 468: Predicted User: 51, True User: 51
# Sample 469: Predicted User: 51, True User: 51
# Sample 470: Predicted User: 52, True User: 52
# Sample 471: Predicted User: 52, True User: 52
# Sample 472: Predicted User: 52, True User: 52
# Sample 473: Predicted User: 52, True User: 52
# Sample 474: Predicted User: 52, True User: 52
# Sample 475: Predicted User: 52, True User: 52
# Sample 476: Predicted User: 52, True User: 52
# Sample 477: Predicted User: 52, True User: 52
# Sample 478: Predicted User: 52, True User: 52
# Sample 479: Predicted User: 52, True User: 52
# Sample 480: Predicted User: 53, True User: 53
# Sample 481: Predicted User: 53, True User: 53
# Sample 482: Predicted User: 53, True User: 53
# Sample 483: Predicted User: 53, True User: 53
# Sample 484: Predicted User: 53, True User: 53
# Sample 485: Predicted User: 53, True User: 53
# Sample 486: Predicted User: 53, True User: 53
# Sample 487: Predicted User: 53, True User: 53
# Sample 488: Predicted User: 53, True User: 53
# Sample 489: Predicted User: 53, True User: 53
# Sample 490: Predicted User: 55, True User: 55
# Sample 491: Predicted User: 55, True User: 55
# Sample 492: Predicted User: 55, True User: 55
# Sample 493: Predicted User: 55, True User: 55
# Sample 494: Predicted User: 55, True User: 55
# Sample 495: Predicted User: 55, True User: 55
# Sample 496: Predicted User: 55, True User: 55
# Sample 497: Predicted User: 55, True User: 55
# Sample 498: Predicted User: 55, True User: 55
# Sample 499: Predicted User: 55, True User: 55
# Sample 500: Predicted User: 56, True User: 56
# Sample 501: Predicted User: 56, True User: 56
# Sample 502: Predicted User: 56, True User: 56
# Sample 503: Predicted User: 56, True User: 56
# Sample 504: Predicted User: 56, True User: 56
# Sample 505: Predicted User: 56, True User: 56
# Sample 506: Predicted User: 56, True User: 56
# Sample 507: Predicted User: 56, True User: 56
# Sample 508: Predicted User: 56, True User: 56
# Sample 509: Predicted User: 56, True User: 56
# Sample 510: Predicted User: 57, True User: 57
# Sample 511: Predicted User: 57, True User: 57
# Sample 512: Predicted User: 57, True User: 57
# Sample 513: Predicted User: 57, True User: 57
# Sample 514: Predicted User: 57, True User: 57
# Sample 515: Predicted User: 57, True User: 57
# Sample 516: Predicted User: 57, True User: 57
# Sample 517: Predicted User: 57, True User: 57
# Sample 518: Predicted User: 57, True User: 57
# Sample 519: Predicted User: 57, True User: 57
# Sample 520: Predicted User: 58, True User: 58
# Sample 521: Predicted User: 58, True User: 58
# Sample 522: Predicted User: 58, True User: 58
# Sample 523: Predicted User: 58, True User: 58
# Sample 524: Predicted User: 58, True User: 58
# Sample 525: Predicted User: 58, True User: 58
# Sample 526: Predicted User: 58, True User: 58
# Sample 527: Predicted User: 58, True User: 58
# Sample 528: Predicted User: 58, True User: 58
# Sample 529: Predicted User: 58, True User: 58
# Sample 530: Predicted User: 60, True User: 60
# Sample 531: Predicted User: 60, True User: 60
# Sample 532: Predicted User: 60, True User: 60
# Sample 533: Predicted User: 60, True User: 60
# Sample 534: Predicted User: 60, True User: 60
# Sample 535: Predicted User: 60, True User: 60
# Sample 536: Predicted User: 60, True User: 60
# Sample 537: Predicted User: 60, True User: 60
# Sample 538: Predicted User: 60, True User: 60
# Sample 539: Predicted User: 60, True User: 60
# Sample 540: Predicted User: 62, True User: 62
# Sample 541: Predicted User: 62, True User: 62
# Sample 542: Predicted User: 62, True User: 62
# Sample 543: Predicted User: 62, True User: 62
# Sample 544: Predicted User: 62, True User: 62
# Sample 545: Predicted User: 62, True User: 62
# Sample 546: Predicted User: 62, True User: 62
# Sample 547: Predicted User: 62, True User: 62
# Sample 548: Predicted User: 62, True User: 62
# Sample 549: Predicted User: 62, True User: 62
# Sample 550: Predicted User: 63, True User: 63
# Sample 551: Predicted User: 63, True User: 63
# Sample 552: Predicted User: 63, True User: 63
# Sample 553: Predicted User: 63, True User: 63
# Sample 554: Predicted User: 63, True User: 63
# Sample 555: Predicted User: 63, True User: 63
# Sample 556: Predicted User: 63, True User: 63
# Sample 557: Predicted User: 63, True User: 63
# Sample 558: Predicted User: 63, True User: 63
# Sample 559: Predicted User: 63, True User: 63
# Sample 560: Predicted User: 65, True User: 65
# Sample 561: Predicted User: 65, True User: 65
# Sample 562: Predicted User: 65, True User: 65
# Sample 563: Predicted User: 65, True User: 65
# Sample 564: Predicted User: 65, True User: 65
# Sample 565: Predicted User: 65, True User: 65
# Sample 566: Predicted User: 65, True User: 65
# Sample 567: Predicted User: 65, True User: 65
# Sample 568: Predicted User: 65, True User: 65
# Sample 569: Predicted User: 65, True User: 65
# Sample 570: Predicted User: 66, True User: 66
# Sample 571: Predicted User: 66, True User: 66
# Sample 572: Predicted User: 66, True User: 66
# Sample 573: Predicted User: 66, True User: 66
# Sample 574: Predicted User: 66, True User: 66
# Sample 575: Predicted User: 66, True User: 66
# Sample 576: Predicted User: 66, True User: 66
# Sample 577: Predicted User: 66, True User: 66
# Sample 578: Predicted User: 66, True User: 66
# Sample 579: Predicted User: 66, True User: 66
# Sample 580: Predicted User: 67, True User: 67
# Sample 581: Predicted User: 67, True User: 67
# Sample 582: Predicted User: 67, True User: 67
# Sample 583: Predicted User: 67, True User: 67
# Sample 584: Predicted User: 67, True User: 67
# Sample 585: Predicted User: 67, True User: 67
# Sample 586: Predicted User: 67, True User: 67
# Sample 587: Predicted User: 67, True User: 67
# Sample 588: Predicted User: 67, True User: 67
# Sample 589: Predicted User: 67, True User: 67
# Sample 590: Predicted User: 69, True User: 69
# Sample 591: Predicted User: 69, True User: 69
# Sample 592: Predicted User: 69, True User: 69
# Sample 593: Predicted User: 69, True User: 69
# Sample 594: Predicted User: 69, True User: 69
# Sample 595: Predicted User: 69, True User: 69
# Sample 596: Predicted User: 69, True User: 69
# Sample 597: Predicted User: 69, True User: 69
# Sample 598: Predicted User: 69, True User: 69
# Sample 599: Predicted User: 69, True User: 69
# Sample 600: Predicted User: 70, True User: 70
# Sample 601: Predicted User: 70, True User: 70
# Sample 602: Predicted User: 70, True User: 70
# Sample 603: Predicted User: 70, True User: 70
# Sample 604: Predicted User: 70, True User: 70
# Sample 605: Predicted User: 70, True User: 70
# Sample 606: Predicted User: 70, True User: 70
# Sample 607: Predicted User: 70, True User: 70
# Sample 608: Predicted User: 70, True User: 70
# Sample 609: Predicted User: 70, True User: 70
# Sample 610: Predicted User: 72, True User: 72
# Sample 611: Predicted User: 72, True User: 72
# Sample 612: Predicted User: 72, True User: 72
# Sample 613: Predicted User: 72, True User: 72
# Sample 614: Predicted User: 72, True User: 72
# Sample 615: Predicted User: 72, True User: 72
# Sample 616: Predicted User: 72, True User: 72
# Sample 617: Predicted User: 72, True User: 72
# Sample 618: Predicted User: 72, True User: 72
# Sample 619: Predicted User: 72, True User: 72
# Sample 620: Predicted User: 73, True User: 73
# Sample 621: Predicted User: 73, True User: 73
# Sample 622: Predicted User: 73, True User: 73
# Sample 623: Predicted User: 73, True User: 73
# Sample 624: Predicted User: 73, True User: 73
# Sample 625: Predicted User: 73, True User: 73
# Sample 626: Predicted User: 73, True User: 73
# Sample 627: Predicted User: 73, True User: 73
# Sample 628: Predicted User: 73, True User: 73
# Sample 629: Predicted User: 73, True User: 73
# Sample 630: Predicted User: 74, True User: 74
# Sample 631: Predicted User: 74, True User: 74
# Sample 632: Predicted User: 74, True User: 74
# Sample 633: Predicted User: 74, True User: 74
# Sample 634: Predicted User: 74, True User: 74
# Sample 635: Predicted User: 74, True User: 74
# Sample 636: Predicted User: 74, True User: 74
# Sample 637: Predicted User: 74, True User: 74
# Sample 638: Predicted User: 74, True User: 74
# Sample 639: Predicted User: 74, True User: 74
# Sample 640: Predicted User: 75, True User: 75
# Sample 641: Predicted User: 75, True User: 75
# Sample 642: Predicted User: 75, True User: 75
# Sample 643: Predicted User: 75, True User: 75
# Sample 644: Predicted User: 75, True User: 75
# Sample 645: Predicted User: 75, True User: 75
# Sample 646: Predicted User: 75, True User: 75
# Sample 647: Predicted User: 75, True User: 75
# Sample 648: Predicted User: 75, True User: 75
# Sample 649: Predicted User: 75, True User: 75
# Sample 650: Predicted User: 76, True User: 76
# Sample 651: Predicted User: 76, True User: 76
# Sample 652: Predicted User: 76, True User: 76
# Sample 653: Predicted User: 76, True User: 76
# Sample 654: Predicted User: 76, True User: 76
# Sample 655: Predicted User: 76, True User: 76
# Sample 656: Predicted User: 76, True User: 76
# Sample 657: Predicted User: 76, True User: 76
# Sample 658: Predicted User: 76, True User: 76
# Sample 659: Predicted User: 76, True User: 76
# Sample 660: Predicted User: 77, True User: 77
# Sample 661: Predicted User: 77, True User: 77
# Sample 662: Predicted User: 77, True User: 77
# Sample 663: Predicted User: 77, True User: 77
# Sample 664: Predicted User: 77, True User: 77
# Sample 665: Predicted User: 77, True User: 77
# Sample 666: Predicted User: 77, True User: 77
# Sample 667: Predicted User: 77, True User: 77
# Sample 668: Predicted User: 77, True User: 77
# Sample 669: Predicted User: 77, True User: 77
# Sample 670: Predicted User: 78, True User: 78
# Sample 671: Predicted User: 78, True User: 78
# Sample 672: Predicted User: 78, True User: 78
# Sample 673: Predicted User: 78, True User: 78
# Sample 674: Predicted User: 78, True User: 78
# Sample 675: Predicted User: 78, True User: 78
# Sample 676: Predicted User: 78, True User: 78
# Sample 677: Predicted User: 78, True User: 78
# Sample 678: Predicted User: 78, True User: 78
# Sample 679: Predicted User: 78, True User: 78
# Sample 680: Predicted User: 79, True User: 79
# Sample 681: Predicted User: 79, True User: 79
# Sample 682: Predicted User: 79, True User: 79
# Sample 683: Predicted User: 79, True User: 79
# Sample 684: Predicted User: 79, True User: 79
# Sample 685: Predicted User: 79, True User: 79
# Sample 686: Predicted User: 79, True User: 79
# Sample 687: Predicted User: 79, True User: 79
# Sample 688: Predicted User: 79, True User: 79
# Sample 689: Predicted User: 79, True User: 79
# Sample 690: Predicted User: 80, True User: 80
# Sample 691: Predicted User: 80, True User: 80
# Sample 692: Predicted User: 80, True User: 80
# Sample 693: Predicted User: 80, True User: 80
# Sample 694: Predicted User: 80, True User: 80
# Sample 695: Predicted User: 80, True User: 80
# Sample 696: Predicted User: 80, True User: 80
# Sample 697: Predicted User: 80, True User: 80
# Sample 698: Predicted User: 80, True User: 80
# Sample 699: Predicted User: 80, True User: 80
# Sample 700: Predicted User: 82, True User: 82
# Sample 701: Predicted User: 82, True User: 82
# Sample 702: Predicted User: 82, True User: 82
# Sample 703: Predicted User: 82, True User: 82
# Sample 704: Predicted User: 82, True User: 82
# Sample 705: Predicted User: 82, True User: 82
# Sample 706: Predicted User: 82, True User: 82
# Sample 707: Predicted User: 82, True User: 82
# Sample 708: Predicted User: 82, True User: 82
# Sample 709: Predicted User: 82, True User: 82
# Sample 710: Predicted User: 83, True User: 83
# Sample 711: Predicted User: 83, True User: 83
# Sample 712: Predicted User: 83, True User: 83
# Sample 713: Predicted User: 83, True User: 83
# Sample 714: Predicted User: 83, True User: 83
# Sample 715: Predicted User: 83, True User: 83
# Sample 716: Predicted User: 83, True User: 83
# Sample 717: Predicted User: 83, True User: 83
# Sample 718: Predicted User: 83, True User: 83
# Sample 719: Predicted User: 83, True User: 83
# Sample 720: Predicted User: 85, True User: 85
# Sample 721: Predicted User: 85, True User: 85
# Sample 722: Predicted User: 85, True User: 85
# Sample 723: Predicted User: 85, True User: 85
# Sample 724: Predicted User: 85, True User: 85
# Sample 725: Predicted User: 85, True User: 85
# Sample 726: Predicted User: 85, True User: 85
# Sample 727: Predicted User: 85, True User: 85
# Sample 728: Predicted User: 85, True User: 85
# Sample 729: Predicted User: 85, True User: 85
# Sample 730: Predicted User: 86, True User: 86
# Sample 731: Predicted User: 86, True User: 86
# Sample 732: Predicted User: 86, True User: 86
# Sample 733: Predicted User: 86, True User: 86
# Sample 734: Predicted User: 86, True User: 86
# Sample 735: Predicted User: 86, True User: 86
# Sample 736: Predicted User: 86, True User: 86
# Sample 737: Predicted User: 86, True User: 86
# Sample 738: Predicted User: 86, True User: 86
# Sample 739: Predicted User: 86, True User: 86
# Sample 740: Predicted User: 87, True User: 87
# Sample 741: Predicted User: 87, True User: 87
# Sample 742: Predicted User: 87, True User: 87
# Sample 743: Predicted User: 87, True User: 87
# Sample 744: Predicted User: 87, True User: 87
# Sample 745: Predicted User: 87, True User: 87
# Sample 746: Predicted User: 87, True User: 87
# Sample 747: Predicted User: 87, True User: 87
# Sample 748: Predicted User: 87, True User: 87
# Sample 749: Predicted User: 87, True User: 87
# Sample 750: Predicted User: 88, True User: 88
# Sample 751: Predicted User: 88, True User: 88
# Sample 752: Predicted User: 88, True User: 88
# Sample 753: Predicted User: 88, True User: 88
# Sample 754: Predicted User: 88, True User: 88
# Sample 755: Predicted User: 88, True User: 88
# Sample 756: Predicted User: 88, True User: 88
# Sample 757: Predicted User: 88, True User: 88
# Sample 758: Predicted User: 88, True User: 88
# Sample 759: Predicted User: 88, True User: 88
# Sample 760: Predicted User: 89, True User: 89
# Sample 761: Predicted User: 89, True User: 89
# Sample 762: Predicted User: 89, True User: 89
# Sample 763: Predicted User: 89, True User: 89
# Sample 764: Predicted User: 89, True User: 89
# Sample 765: Predicted User: 89, True User: 89
# Sample 766: Predicted User: 89, True User: 89
# Sample 767: Predicted User: 89, True User: 89
# Sample 768: Predicted User: 89, True User: 89
# Sample 769: Predicted User: 89, True User: 89
# Sample 770: Predicted User: 90, True User: 90
# Sample 771: Predicted User: 90, True User: 90
# Sample 772: Predicted User: 90, True User: 90
# Sample 773: Predicted User: 90, True User: 90
# Sample 774: Predicted User: 90, True User: 90
# Sample 775: Predicted User: 90, True User: 90
# Sample 776: Predicted User: 90, True User: 90
# Sample 777: Predicted User: 90, True User: 90
# Sample 778: Predicted User: 90, True User: 90
# Sample 779: Predicted User: 90, True User: 90
# Sample 780: Predicted User: 91, True User: 91
# Sample 781: Predicted User: 91, True User: 91
# Sample 782: Predicted User: 91, True User: 91
# Sample 783: Predicted User: 91, True User: 91
# Sample 784: Predicted User: 91, True User: 91
# Sample 785: Predicted User: 91, True User: 91
# Sample 786: Predicted User: 91, True User: 91
# Sample 787: Predicted User: 91, True User: 91
# Sample 788: Predicted User: 91, True User: 91
# Sample 789: Predicted User: 91, True User: 91
# Sample 790: Predicted User: 92, True User: 92
# Sample 791: Predicted User: 92, True User: 92
# Sample 792: Predicted User: 92, True User: 92
# Sample 793: Predicted User: 92, True User: 92
# Sample 794: Predicted User: 92, True User: 92
# Sample 795: Predicted User: 92, True User: 92
# Sample 796: Predicted User: 92, True User: 92
# Sample 797: Predicted User: 92, True User: 92
# Sample 798: Predicted User: 92, True User: 92
# Sample 799: Predicted User: 92, True User: 92
# Sample 800: Predicted User: 93, True User: 93
# Sample 801: Predicted User: 93, True User: 93
# Sample 802: Predicted User: 93, True User: 93
# Sample 803: Predicted User: 93, True User: 93
# Sample 804: Predicted User: 93, True User: 93
# Sample 805: Predicted User: 93, True User: 93
# Sample 806: Predicted User: 93, True User: 93
# Sample 807: Predicted User: 93, True User: 93
# Sample 808: Predicted User: 93, True User: 93
# Sample 809: Predicted User: 93, True User: 93
# Sample 810: Predicted User: 94, True User: 94
# Sample 811: Predicted User: 94, True User: 94
# Sample 812: Predicted User: 94, True User: 94
# Sample 813: Predicted User: 94, True User: 94
# Sample 814: Predicted User: 94, True User: 94
# Sample 815: Predicted User: 94, True User: 94
# Sample 816: Predicted User: 94, True User: 94
# Sample 817: Predicted User: 94, True User: 94
# Sample 818: Predicted User: 94, True User: 94
# Sample 819: Predicted User: 94, True User: 94
# Sample 820: Predicted User: 95, True User: 95
# Sample 821: Predicted User: 95, True User: 95
# Sample 822: Predicted User: 95, True User: 95
# Sample 823: Predicted User: 95, True User: 95
# Sample 824: Predicted User: 95, True User: 95
# Sample 825: Predicted User: 95, True User: 95
# Sample 826: Predicted User: 95, True User: 95
# Sample 827: Predicted User: 95, True User: 95
# Sample 828: Predicted User: 95, True User: 95
# Sample 829: Predicted User: 95, True User: 95
# Sample 830: Predicted User: 96, True User: 96
# Sample 831: Predicted User: 96, True User: 96
# Sample 832: Predicted User: 96, True User: 96
# Sample 833: Predicted User: 96, True User: 96
# Sample 834: Predicted User: 96, True User: 96
# Sample 835: Predicted User: 96, True User: 96
# Sample 836: Predicted User: 96, True User: 96
# Sample 837: Predicted User: 96, True User: 96
# Sample 838: Predicted User: 96, True User: 96
# Sample 839: Predicted User: 96, True User: 96
# Sample 840: Predicted User: 97, True User: 97
# Sample 841: Predicted User: 97, True User: 97
# Sample 842: Predicted User: 97, True User: 97
# Sample 843: Predicted User: 97, True User: 97
# Sample 844: Predicted User: 97, True User: 97
# Sample 845: Predicted User: 97, True User: 97
# Sample 846: Predicted User: 97, True User: 97
# Sample 847: Predicted User: 97, True User: 97
# Sample 848: Predicted User: 97, True User: 97
# Sample 849: Predicted User: 97, True User: 97
# Sample 850: Predicted User: 98, True User: 98
# Sample 851: Predicted User: 98, True User: 98
# Sample 852: Predicted User: 98, True User: 98
# Sample 853: Predicted User: 98, True User: 98
# Sample 854: Predicted User: 98, True User: 98
# Sample 855: Predicted User: 98, True User: 98
# Sample 856: Predicted User: 98, True User: 98
# Sample 857: Predicted User: 98, True User: 98
# Sample 858: Predicted User: 98, True User: 98
# Sample 859: Predicted User: 98, True User: 98
# Sample 860: Predicted User: 99, True User: 99
# Sample 861: Predicted User: 99, True User: 99
# Sample 862: Predicted User: 99, True User: 99
# Sample 863: Predicted User: 99, True User: 99
# Sample 864: Predicted User: 99, True User: 99
# Sample 865: Predicted User: 99, True User: 99
# Sample 866: Predicted User: 99, True User: 99
# Sample 867: Predicted User: 99, True User: 99
# Sample 868: Predicted User: 99, True User: 99
# Sample 869: Predicted User: 99, True User: 99
# Sample 870: Predicted User: 100, True User: 100
# Sample 871: Predicted User: 100, True User: 100
# Sample 872: Predicted User: 100, True User: 100
# Sample 873: Predicted User: 100, True User: 100
# Sample 874: Predicted User: 100, True User: 100
# Sample 875: Predicted User: 100, True User: 100
# Sample 876: Predicted User: 100, True User: 100
# Sample 877: Predicted User: 100, True User: 100
# Sample 878: Predicted User: 100, True User: 100
# Sample 879: Predicted User: 100, True User: 100
# Sample 880: Predicted User: 101, True User: 101
# Sample 881: Predicted User: 101, True User: 101
# Sample 882: Predicted User: 101, True User: 101
# Sample 883: Predicted User: 101, True User: 101
# Sample 884: Predicted User: 101, True User: 101
# Sample 885: Predicted User: 101, True User: 101
# Sample 886: Predicted User: 101, True User: 101
# Sample 887: Predicted User: 101, True User: 101
# Sample 888: Predicted User: 101, True User: 101
# Sample 889: Predicted User: 101, True User: 101
# Sample 890: Predicted User: 102, True User: 102
# Sample 891: Predicted User: 102, True User: 102
# Sample 892: Predicted User: 102, True User: 102
# Sample 893: Predicted User: 102, True User: 102
# Sample 894: Predicted User: 102, True User: 102
# Sample 895: Predicted User: 102, True User: 102
# Sample 896: Predicted User: 102, True User: 102
# Sample 897: Predicted User: 102, True User: 102
# Sample 898: Predicted User: 102, True User: 102
# Sample 899: Predicted User: 102, True User: 102
# Sample 900: Predicted User: 103, True User: 103
# Sample 901: Predicted User: 103, True User: 103
# Sample 902: Predicted User: 103, True User: 103
# Sample 903: Predicted User: 103, True User: 103
# Sample 904: Predicted User: 103, True User: 103
# Sample 905: Predicted User: 103, True User: 103
# Sample 906: Predicted User: 103, True User: 103
# Sample 907: Predicted User: 103, True User: 103
# Sample 908: Predicted User: 103, True User: 103
# Sample 909: Predicted User: 103, True User: 103
# Sample 910: Predicted User: 104, True User: 104
# Sample 911: Predicted User: 104, True User: 104
# Sample 912: Predicted User: 104, True User: 104
# Sample 913: Predicted User: 104, True User: 104
# Sample 914: Predicted User: 104, True User: 104
# Sample 915: Predicted User: 104, True User: 104
# Sample 916: Predicted User: 104, True User: 104
# Sample 917: Predicted User: 104, True User: 104
# Sample 918: Predicted User: 104, True User: 104
# Sample 919: Predicted User: 104, True User: 104
# Sample 920: Predicted User: 105, True User: 105
# Sample 921: Predicted User: 105, True User: 105
# Sample 922: Predicted User: 105, True User: 105
# Sample 923: Predicted User: 105, True User: 105
# Sample 924: Predicted User: 105, True User: 105
# Sample 925: Predicted User: 105, True User: 105
# Sample 926: Predicted User: 105, True User: 105
# Sample 927: Predicted User: 105, True User: 105
# Sample 928: Predicted User: 105, True User: 105
# Sample 929: Predicted User: 105, True User: 105
# Sample 930: Predicted User: 106, True User: 106
# Sample 931: Predicted User: 106, True User: 106
# Sample 932: Predicted User: 106, True User: 106
# Sample 933: Predicted User: 106, True User: 106
# Sample 934: Predicted User: 106, True User: 106
# Sample 935: Predicted User: 106, True User: 106
# Sample 936: Predicted User: 106, True User: 106
# Sample 937: Predicted User: 106, True User: 106
# Sample 938: Predicted User: 106, True User: 106
# Sample 939: Predicted User: 106, True User: 106
# Sample 940: Predicted User: 255, True User: 107
# Sample 941: Predicted User: 107, True User: 107
# Sample 942: Predicted User: 107, True User: 107
# Sample 943: Predicted User: 107, True User: 107
# Sample 944: Predicted User: 107, True User: 107
# Sample 945: Predicted User: 425, True User: 107
# Sample 946: Predicted User: 107, True User: 107
# Sample 947: Predicted User: 107, True User: 107
# Sample 948: Predicted User: 107, True User: 107
# Sample 949: Predicted User: 107, True User: 107
# Sample 950: Predicted User: 108, True User: 108
# Sample 951: Predicted User: 108, True User: 108
# Sample 952: Predicted User: 108, True User: 108
# Sample 953: Predicted User: 108, True User: 108
# Sample 954: Predicted User: 108, True User: 108
# Sample 955: Predicted User: 108, True User: 108
# Sample 956: Predicted User: 108, True User: 108
# Sample 957: Predicted User: 108, True User: 108
# Sample 958: Predicted User: 108, True User: 108
# Sample 959: Predicted User: 108, True User: 108
# Sample 960: Predicted User: 109, True User: 109
# Sample 961: Predicted User: 109, True User: 109
# Sample 962: Predicted User: 109, True User: 109
# Sample 963: Predicted User: 109, True User: 109
# Sample 964: Predicted User: 109, True User: 109
# Sample 965: Predicted User: 109, True User: 109
# Sample 966: Predicted User: 109, True User: 109
# Sample 967: Predicted User: 109, True User: 109
# Sample 968: Predicted User: 109, True User: 109
# Sample 969: Predicted User: 109, True User: 109
# Sample 970: Predicted User: 111, True User: 111
# Sample 971: Predicted User: 111, True User: 111
# Sample 972: Predicted User: 111, True User: 111
# Sample 973: Predicted User: 111, True User: 111
# Sample 974: Predicted User: 111, True User: 111
# Sample 975: Predicted User: 111, True User: 111
# Sample 976: Predicted User: 111, True User: 111
# Sample 977: Predicted User: 111, True User: 111
# Sample 978: Predicted User: 425, True User: 111
# Sample 979: Predicted User: 111, True User: 111
# Sample 980: Predicted User: 112, True User: 112
# Sample 981: Predicted User: 112, True User: 112
# Sample 982: Predicted User: 112, True User: 112
# Sample 983: Predicted User: 112, True User: 112
# Sample 984: Predicted User: 112, True User: 112
# Sample 985: Predicted User: 112, True User: 112
# Sample 986: Predicted User: 112, True User: 112
# Sample 987: Predicted User: 112, True User: 112
# Sample 988: Predicted User: 112, True User: 112
# Sample 989: Predicted User: 112, True User: 112
# Sample 990: Predicted User: 113, True User: 113
# Sample 991: Predicted User: 113, True User: 113
# Sample 992: Predicted User: 113, True User: 113
# Sample 993: Predicted User: 113, True User: 113
# Sample 994: Predicted User: 113, True User: 113
# Sample 995: Predicted User: 113, True User: 113
# Sample 996: Predicted User: 113, True User: 113
# Sample 997: Predicted User: 113, True User: 113
# Sample 998: Predicted User: 113, True User: 113
# Sample 999: Predicted User: 113, True User: 113
# Sample 1000: Predicted User: 114, True User: 114
# Sample 1001: Predicted User: 114, True User: 114
# Sample 1002: Predicted User: 114, True User: 114
# Sample 1003: Predicted User: 114, True User: 114
# Sample 1004: Predicted User: 114, True User: 114
# Sample 1005: Predicted User: 114, True User: 114
# Sample 1006: Predicted User: 114, True User: 114
# Sample 1007: Predicted User: 114, True User: 114
# Sample 1008: Predicted User: 114, True User: 114
# Sample 1009: Predicted User: 114, True User: 114
# Sample 1010: Predicted User: 115, True User: 115
# Sample 1011: Predicted User: 115, True User: 115
# Sample 1012: Predicted User: 115, True User: 115
# Sample 1013: Predicted User: 115, True User: 115
# Sample 1014: Predicted User: 115, True User: 115
# Sample 1015: Predicted User: 115, True User: 115
# Sample 1016: Predicted User: 115, True User: 115
# Sample 1017: Predicted User: 115, True User: 115
# Sample 1018: Predicted User: 115, True User: 115
# Sample 1019: Predicted User: 115, True User: 115
# Sample 1020: Predicted User: 116, True User: 116
# Sample 1021: Predicted User: 116, True User: 116
# Sample 1022: Predicted User: 116, True User: 116
# Sample 1023: Predicted User: 116, True User: 116
# Sample 1024: Predicted User: 116, True User: 116
# Sample 1025: Predicted User: 116, True User: 116
# Sample 1026: Predicted User: 116, True User: 116
# Sample 1027: Predicted User: 116, True User: 116
# Sample 1028: Predicted User: 116, True User: 116
# Sample 1029: Predicted User: 116, True User: 116
# Sample 1030: Predicted User: 117, True User: 117
# Sample 1031: Predicted User: 117, True User: 117
# Sample 1032: Predicted User: 117, True User: 117
# Sample 1033: Predicted User: 117, True User: 117
# Sample 1034: Predicted User: 117, True User: 117
# Sample 1035: Predicted User: 117, True User: 117
# Sample 1036: Predicted User: 117, True User: 117
# Sample 1037: Predicted User: 117, True User: 117
# Sample 1038: Predicted User: 117, True User: 117
# Sample 1039: Predicted User: 117, True User: 117
# Sample 1040: Predicted User: 118, True User: 118
# Sample 1041: Predicted User: 118, True User: 118
# Sample 1042: Predicted User: 118, True User: 118
# Sample 1043: Predicted User: 118, True User: 118
# Sample 1044: Predicted User: 118, True User: 118
# Sample 1045: Predicted User: 118, True User: 118
# Sample 1046: Predicted User: 118, True User: 118
# Sample 1047: Predicted User: 118, True User: 118
# Sample 1048: Predicted User: 118, True User: 118
# Sample 1049: Predicted User: 118, True User: 118
# Sample 1050: Predicted User: 119, True User: 119
# Sample 1051: Predicted User: 119, True User: 119
# Sample 1052: Predicted User: 119, True User: 119
# Sample 1053: Predicted User: 119, True User: 119
# Sample 1054: Predicted User: 119, True User: 119
# Sample 1055: Predicted User: 119, True User: 119
# Sample 1056: Predicted User: 119, True User: 119
# ...
# Sample 4711: Predicted User: 271, True User: 271
# Sample 4712: Predicted User: 271, True User: 271
# Sample 4713: Predicted User: 271, True User: 271
# Sample 4714: Predicted User: 271, True User: 271
# Sample 4715: Predicted User: 271, True User: 271
# Sample 4716: Predicted User: 271, True User: 271
# Sample 4717: Predicted User: 271, True User: 271
# Sample 4718: Predicted User: 271, True User: 271
# Sample 4719: Predicted User: 271, True User: 271
# Sample 4720: Predicted User: 274, True User: 274
# Sample 4721: Predicted User: 274, True User: 274
# Sample 4722: Predicted User: 274, True User: 274
# Sample 4723: Predicted User: 271, True User: 274
# Sample 4724: Predicted User: 274, True User: 274
# Sample 4725: Predicted User: 274, True User: 274
# Sample 4726: Predicted User: 274, True User: 274
# Sample 4727: Predicted User: 274, True User: 274
# Sample 4728: Predicted User: 274, True User: 274
# Sample 4729: Predicted User: 274, True User: 274
# Sample 4730: Predicted User: 284, True User: 284
# Sample 4731: Predicted User: 284, True User: 284
# Sample 4732: Predicted User: 199, True User: 284
# Sample 4733: Predicted User: 284, True User: 284
# Sample 4734: Predicted User: 284, True User: 284
# Sample 4735: Predicted User: 284, True User: 284
# Sample 4736: Predicted User: 284, True User: 284
# Sample 4737: Predicted User: 276, True User: 284
# Sample 4738: Predicted User: 284, True User: 284
# Sample 4739: Predicted User: 284, True User: 284
# Sample 4740: Predicted User: 285, True User: 285
# Sample 4741: Predicted User: 285, True User: 285
# Sample 4742: Predicted User: 285, True User: 285
# Sample 4743: Predicted User: 285, True User: 285
# Sample 4744: Predicted User: 285, True User: 285
# Sample 4745: Predicted User: 285, True User: 285
# Sample 4746: Predicted User: 285, True User: 285
# Sample 4747: Predicted User: 285, True User: 285
# Sample 4748: Predicted User: 285, True User: 285
# Sample 4749: Predicted User: 285, True User: 285
# Sample 4750: Predicted User: 290, True User: 290
# Sample 4751: Predicted User: 290, True User: 290
# Sample 4752: Predicted User: 290, True User: 290
# Sample 4753: Predicted User: 290, True User: 290
# Sample 4754: Predicted User: 290, True User: 290
# Sample 4755: Predicted User: 290, True User: 290
# Sample 4756: Predicted User: 290, True User: 290
# Sample 4757: Predicted User: 290, True User: 290
# Sample 4758: Predicted User: 290, True User: 290
# Sample 4759: Predicted User: 290, True User: 290
# Sample 4760: Predicted User: 298, True User: 298
# Sample 4761: Predicted User: 298, True User: 298
# Sample 4762: Predicted User: 298, True User: 298
# Sample 4763: Predicted User: 298, True User: 298
# Sample 4764: Predicted User: 298, True User: 298
# Sample 4765: Predicted User: 298, True User: 298
# Sample 4766: Predicted User: 298, True User: 298
# Sample 4767: Predicted User: 298, True User: 298
# Sample 4768: Predicted User: 298, True User: 298
# Sample 4769: Predicted User: 298, True User: 298
# Sample 4770: Predicted User: 300, True User: 300
# Sample 4771: Predicted User: 300, True User: 300
# Sample 4772: Predicted User: 300, True User: 300
# Sample 4773: Predicted User: 300, True User: 300
# Sample 4774: Predicted User: 300, True User: 300
# Sample 4775: Predicted User: 285, True User: 300
# Sample 4776: Predicted User: 300, True User: 300
# Sample 4777: Predicted User: 300, True User: 300
# Sample 4778: Predicted User: 300, True User: 300
# Sample 4779: Predicted User: 300, True User: 300
# Sample 4780: Predicted User: 308, True User: 308
# Sample 4781: Predicted User: 308, True User: 308
# Sample 4782: Predicted User: 308, True User: 308
# Sample 4783: Predicted User: 308, True User: 308
# Sample 4784: Predicted User: 308, True User: 308
# Sample 4785: Predicted User: 308, True User: 308
# Sample 4786: Predicted User: 308, True User: 308
# Sample 4787: Predicted User: 308, True User: 308
# Sample 4788: Predicted User: 308, True User: 308
# Sample 4789: Predicted User: 308, True User: 308
# Sample 4790: Predicted User: 309, True User: 309
# Sample 4791: Predicted User: 309, True User: 309
# Sample 4792: Predicted User: 309, True User: 309
# Sample 4793: Predicted User: 309, True User: 309
# Sample 4794: Predicted User: 309, True User: 309
# Sample 4795: Predicted User: 309, True User: 309
# Sample 4796: Predicted User: 309, True User: 309
# Sample 4797: Predicted User: 309, True User: 309
# Sample 4798: Predicted User: 309, True User: 309
# Sample 4799: Predicted User: 309, True User: 309
# Sample 4800: Predicted User: 321, True User: 321
# Sample 4801: Predicted User: 321, True User: 321
# Sample 4802: Predicted User: 321, True User: 321
# Sample 4803: Predicted User: 321, True User: 321
# Sample 4804: Predicted User: 321, True User: 321
# Sample 4805: Predicted User: 321, True User: 321
# Sample 4806: Predicted User: 321, True User: 321
# Sample 4807: Predicted User: 321, True User: 321
# Sample 4808: Predicted User: 321, True User: 321
# Sample 4809: Predicted User: 321, True User: 321
# Sample 4810: Predicted User: 325, True User: 325
# Sample 4811: Predicted User: 325, True User: 325
# Sample 4812: Predicted User: 325, True User: 325
# Sample 4813: Predicted User: 325, True User: 325
# Sample 4814: Predicted User: 325, True User: 325
# Sample 4815: Predicted User: 325, True User: 325
# Sample 4816: Predicted User: 325, True User: 325
# Sample 4817: Predicted User: 325, True User: 325
# Sample 4818: Predicted User: 325, True User: 325
# Sample 4819: Predicted User: 325, True User: 325
# Sample 4820: Predicted User: 333, True User: 333
# Sample 4821: Predicted User: 333, True User: 333
# Sample 4822: Predicted User: 333, True User: 333
# Sample 4823: Predicted User: 333, True User: 333
# Sample 4824: Predicted User: 333, True User: 333
# Sample 4825: Predicted User: 333, True User: 333
# Sample 4826: Predicted User: 333, True User: 333
# Sample 4827: Predicted User: 333, True User: 333
# Sample 4828: Predicted User: 333, True User: 333
# Sample 4829: Predicted User: 333, True User: 333
# Sample 4830: Predicted User: 339, True User: 339
# Sample 4831: Predicted User: 339, True User: 339
# Sample 4832: Predicted User: 339, True User: 339
# Sample 4833: Predicted User: 339, True User: 339
# Sample 4834: Predicted User: 339, True User: 339
# Sample 4835: Predicted User: 339, True User: 339
# Sample 4836: Predicted User: 339, True User: 339
# Sample 4837: Predicted User: 339, True User: 339
# Sample 4838: Predicted User: 339, True User: 339
# Sample 4839: Predicted User: 339, True User: 339
# Sample 4840: Predicted User: 345, True User: 345
# Sample 4841: Predicted User: 345, True User: 345
# Sample 4842: Predicted User: 345, True User: 345
# Sample 4843: Predicted User: 345, True User: 345
# Sample 4844: Predicted User: 345, True User: 345
# Sample 4845: Predicted User: 345, True User: 345
# Sample 4846: Predicted User: 345, True User: 345
# Sample 4847: Predicted User: 345, True User: 345
# Sample 4848: Predicted User: 345, True User: 345
# Sample 4849: Predicted User: 345, True User: 345
# Sample 4850: Predicted User: 348, True User: 348
# Sample 4851: Predicted User: 348, True User: 348
# Sample 4852: Predicted User: 348, True User: 348
# Sample 4853: Predicted User: 348, True User: 348
# Sample 4854: Predicted User: 348, True User: 348
# Sample 4855: Predicted User: 348, True User: 348
# Sample 4856: Predicted User: 348, True User: 348
# Sample 4857: Predicted User: 348, True User: 348
# Sample 4858: Predicted User: 348, True User: 348
# Sample 4859: Predicted User: 348, True User: 348
# Sample 4860: Predicted User: 355, True User: 355
# Sample 4861: Predicted User: 355, True User: 355
# Sample 4862: Predicted User: 355, True User: 355
# Sample 4863: Predicted User: 355, True User: 355
# Sample 4864: Predicted User: 355, True User: 355
# Sample 4865: Predicted User: 355, True User: 355
# Sample 4866: Predicted User: 355, True User: 355
# Sample 4867: Predicted User: 355, True User: 355
# Sample 4868: Predicted User: 355, True User: 355
# Sample 4869: Predicted User: 355, True User: 355
# Sample 4870: Predicted User: 358, True User: 358
# Sample 4871: Predicted User: 358, True User: 358
# Sample 4872: Predicted User: 358, True User: 358
# Sample 4873: Predicted User: 358, True User: 358
# Sample 4874: Predicted User: 358, True User: 358
# Sample 4875: Predicted User: 358, True User: 358
# Sample 4876: Predicted User: 358, True User: 358
# Sample 4877: Predicted User: 358, True User: 358
# Sample 4878: Predicted User: 358, True User: 358
# Sample 4879: Predicted User: 358, True User: 358
# Sample 4880: Predicted User: 362, True User: 362
# Sample 4881: Predicted User: 362, True User: 362
# Sample 4882: Predicted User: 362, True User: 362
# Sample 4883: Predicted User: 362, True User: 362
# Sample 4884: Predicted User: 362, True User: 362
# Sample 4885: Predicted User: 362, True User: 362
# Sample 4886: Predicted User: 362, True User: 362
# Sample 4887: Predicted User: 362, True User: 362
# Sample 4888: Predicted User: 362, True User: 362
# Sample 4889: Predicted User: 362, True User: 362
# Sample 4890: Predicted User: 370, True User: 370
# Sample 4891: Predicted User: 370, True User: 370
# Sample 4892: Predicted User: 370, True User: 370
# Sample 4893: Predicted User: 370, True User: 370
# Sample 4894: Predicted User: 370, True User: 370
# Sample 4895: Predicted User: 370, True User: 370
# Sample 4896: Predicted User: 370, True User: 370
# Sample 4897: Predicted User: 370, True User: 370
# Sample 4898: Predicted User: 370, True User: 370
# Sample 4899: Predicted User: 370, True User: 370
# Sample 4900: Predicted User: 376, True User: 376
# Sample 4901: Predicted User: 376, True User: 376
# Sample 4902: Predicted User: 376, True User: 376
# Sample 4903: Predicted User: 376, True User: 376
# Sample 4904: Predicted User: 376, True User: 376
# Sample 4905: Predicted User: 376, True User: 376
# Sample 4906: Predicted User: 376, True User: 376
# Sample 4907: Predicted User: 376, True User: 376
# Sample 4908: Predicted User: 376, True User: 376
# Sample 4909: Predicted User: 376, True User: 376
# Sample 4910: Predicted User: 377, True User: 377
# Sample 4911: Predicted User: 377, True User: 377
# Sample 4912: Predicted User: 377, True User: 377
# Sample 4913: Predicted User: 377, True User: 377
# Sample 4914: Predicted User: 377, True User: 377
# Sample 4915: Predicted User: 377, True User: 377
# Sample 4916: Predicted User: 377, True User: 377
# Sample 4917: Predicted User: 377, True User: 377
# Sample 4918: Predicted User: 377, True User: 377
# Sample 4919: Predicted User: 377, True User: 377
# Sample 4920: Predicted User: 387, True User: 387
# Sample 4921: Predicted User: 387, True User: 387
# Sample 4922: Predicted User: 387, True User: 387
# Sample 4923: Predicted User: 387, True User: 387
# Sample 4924: Predicted User: 387, True User: 387
# Sample 4925: Predicted User: 387, True User: 387
# Sample 4926: Predicted User: 387, True User: 387
# Sample 4927: Predicted User: 387, True User: 387
# Sample 4928: Predicted User: 387, True User: 387
# Sample 4929: Predicted User: 387, True User: 387
# Sample 4930: Predicted User: 405, True User: 405
# Sample 4931: Predicted User: 405, True User: 405
# Sample 4932: Predicted User: 405, True User: 405
# Sample 4933: Predicted User: 405, True User: 405
# Sample 4934: Predicted User: 405, True User: 405
# Sample 4935: Predicted User: 405, True User: 405
# Sample 4936: Predicted User: 405, True User: 405
# Sample 4937: Predicted User: 405, True User: 405
# Sample 4938: Predicted User: 405, True User: 405
# Sample 4939: Predicted User: 405, True User: 405
# Sample 4940: Predicted User: 420, True User: 420
# Sample 4941: Predicted User: 420, True User: 420
# Sample 4942: Predicted User: 420, True User: 420
# Sample 4943: Predicted User: 420, True User: 420
# Sample 4944: Predicted User: 420, True User: 420
# Sample 4945: Predicted User: 420, True User: 420
# Sample 4946: Predicted User: 420, True User: 420
# Sample 4947: Predicted User: 420, True User: 420
# Sample 4948: Predicted User: 420, True User: 420
# Sample 4949: Predicted User: 420, True User: 420
# Sample 4950: Predicted User: 421, True User: 421
# Sample 4951: Predicted User: 421, True User: 421
# Sample 4952: Predicted User: 421, True User: 421
# Sample 4953: Predicted User: 421, True User: 421
# Sample 4954: Predicted User: 421, True User: 421
# Sample 4955: Predicted User: 421, True User: 421
# Sample 4956: Predicted User: 421, True User: 421
# Sample 4957: Predicted User: 421, True User: 421
# Sample 4958: Predicted User: 421, True User: 421
# Sample 4959: Predicted User: 421, True User: 421
# Sample 4960: Predicted User: 424, True User: 424
# Sample 4961: Predicted User: 424, True User: 424
# Sample 4962: Predicted User: 424, True User: 424
# Sample 4963: Predicted User: 424, True User: 424
# Sample 4964: Predicted User: 424, True User: 424
# Sample 4965: Predicted User: 424, True User: 424
# Sample 4966: Predicted User: 424, True User: 424
# Sample 4967: Predicted User: 424, True User: 424
# Sample 4968: Predicted User: 424, True User: 424
# Sample 4969: Predicted User: 424, True User: 424
# Sample 4970: Predicted User: 433, True User: 433
# Sample 4971: Predicted User: 433, True User: 433
# Sample 4972: Predicted User: 433, True User: 433
# Sample 4973: Predicted User: 433, True User: 433
# Sample 4974: Predicted User: 433, True User: 433
# Sample 4975: Predicted User: 433, True User: 433
# Sample 4976: Predicted User: 433, True User: 433
# Sample 4977: Predicted User: 433, True User: 433
# Sample 4978: Predicted User: 433, True User: 433
# Sample 4979: Predicted User: 433, True User: 433
# Sample 4980: Predicted User: 438, True User: 438
# Sample 4981: Predicted User: 438, True User: 438
# Sample 4982: Predicted User: 438, True User: 438
# Sample 4983: Predicted User: 438, True User: 438
# Sample 4984: Predicted User: 438, True User: 438
# Sample 4985: Predicted User: 438, True User: 438
# Sample 4986: Predicted User: 438, True User: 438
# Sample 4987: Predicted User: 438, True User: 438
# Sample 4988: Predicted User: 438, True User: 438
# Sample 4989: Predicted User: 438, True User: 438
# Sample 4990: Predicted User: 441, True User: 441
# Sample 4991: Predicted User: 441, True User: 441
# Sample 4992: Predicted User: 441, True User: 441
# Sample 4993: Predicted User: 441, True User: 441
# Sample 4994: Predicted User: 441, True User: 441
# Sample 4995: Predicted User: 441, True User: 441
# Sample 4996: Predicted User: 441, True User: 441
# Sample 4997: Predicted User: 441, True User: 441
# Sample 4998: Predicted User: 441, True User: 441
# Sample 4999: Predicted User: 441, True User: 441
# Sample 5000: Predicted User: 450, True User: 450
# Sample 5001: Predicted User: 450, True User: 450
# Sample 5002: Predicted User: 450, True User: 450
# Sample 5003: Predicted User: 450, True User: 450
# Sample 5004: Predicted User: 450, True User: 450
# Sample 5005: Predicted User: 450, True User: 450
# Sample 5006: Predicted User: 450, True User: 450
# Sample 5007: Predicted User: 450, True User: 450
# Sample 5008: Predicted User: 450, True User: 450
# Sample 5009: Predicted User: 450, True User: 450
# Sample 5010: Predicted User: 269, True User: 458
# Sample 5011: Predicted User: 352, True User: 458
# Sample 5012: Predicted User: 458, True User: 458
# Sample 5013: Predicted User: 100, True User: 458
# Sample 5014: Predicted User: 14, True User: 458
# Sample 5015: Predicted User: 112, True User: 458
# Sample 5016: Predicted User: 458, True User: 458
# Sample 5017: Predicted User: 387, True User: 458
# Sample 5018: Predicted User: 165, True User: 458
# Sample 5019: Predicted User: 448, True User: 458
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-a29c7f6f5063> in <cell line: 5>()
#       3
#       4 # Run the prediction on all these indices
# ----> 5 predictions, true_labels = predict_user_data(
#       6     model, test_dataloader, all_user_indices, index_to_user, device
#       7 )
#
# <ipython-input-36-0cbfe789f9c1> in predict_user_data(model, test_dataloader, indexes, index_to_user, device)
#      41             ):
#      42                 if idx in indexes:
# ---> 43                     pred_user = index_to_user[predicted[j].item()]
#      44                     true_user = index_to_user[batch_y[j].item()]
#      45                     all_predictions.append(pred_user)
#
# IndexError: index 28 is out of bounds for dimension 0 with size 28
