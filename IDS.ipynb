# %% [markdown]
# <a href="https://colab.research.google.com/github/antonis00/EKPA/blob/main/IDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.utils import to_categorical
from sklearn.utils import class_weight
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, LSTM
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# URL of the dataset
dataset_url = 'https://raw.githubusercontent.com/kdemertzis/EKPA/main/Data/pcap_data.csv'

def load_dataset(url):
    df = pd.read_csv(url)

    # Assuming the last column is the label
    labels = df.iloc[:, -1].astype('category').cat.codes
    features = df.iloc[:, :-1]

    # Normalize features
    features = (features - features.min()) / (features.max() - features.min())

    # Split the dataset
    train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.20, random_state=42, stratify=labels)
    return train_features.values, train_labels.values, test_features.values, test_labels.values

# Load data
train_data, train_labels, test_data, test_labels = load_dataset(dataset_url)

# Convert labels to categorical
nclass = len(np.unique(train_labels))
train_labels = to_categorical(train_labels, num_classes=nclass)
test_labels = to_categorical(test_labels, num_classes=nclass)

# Get number of features
inshape = train_data.shape[1]

# Define model (Example using a simple Dense network)
def create_model(input_shape, num_classes):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_model(inshape, nclass)
model.summary()

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')
model_checkpoint = ModelCheckpoint('model_best.weights.hdf5', save_best_only=True, monitor='val_accuracy', mode='max')

# Training the model
history = model.fit(train_data, train_labels, epochs=100, batch_size=256, validation_split=0.2, callbacks=[early_stopping, model_checkpoint])

# Load the best model
model.load_weights('model_best.weights.hdf5')

# Predict the classes with the model
predictions = model.predict(test_data)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_labels, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(10,10))
ConfusionMatrixDisplay(confusion_matrix=cm).plot(ax=ax)
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(test_data, test_labels)
print(f'Test Accuracy: {test_acc}')

# Plot training and validation accuracy and loss
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                1664
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 6019 (23.51 KB)
# Trainable params: 6019 (23.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 38/38 [==============================] - 1s 8ms/step - loss: 1.0857 - accuracy: 0.4011 - val_loss: 1.0703 - val_accuracy: 0.4697
# Epoch 2/100
# 38/38 [==============================] - 0s 4ms/step - loss: 1.0587 - accuracy: 0.5418 - val_loss: 1.0462 - val_accuracy: 0.6221
# Epoch 3/100
#  1/38 [..............................] - ETA: 0s - loss: 1.0481 - accuracy: 0.5938
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 0s 4ms/step - loss: 1.0324 - accuracy: 0.6537 - val_loss: 1.0173 - val_accuracy: 0.6727
# Epoch 4/100
# 38/38 [==============================] - 0s 4ms/step - loss: 1.0048 - accuracy: 0.6905 - val_loss: 0.9916 - val_accuracy: 0.6877
# Epoch 5/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9804 - accuracy: 0.7134 - val_loss: 0.9673 - val_accuracy: 0.6973
# Epoch 6/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9565 - accuracy: 0.7182 - val_loss: 0.9427 - val_accuracy: 0.7140
# Epoch 7/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9310 - accuracy: 0.7269 - val_loss: 0.9176 - val_accuracy: 0.7194
# Epoch 8/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9077 - accuracy: 0.7238 - val_loss: 0.8938 - val_accuracy: 0.7299
# Epoch 9/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8848 - accuracy: 0.7313 - val_loss: 0.8711 - val_accuracy: 0.7328
# Epoch 10/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8623 - accuracy: 0.7393 - val_loss: 0.8496 - val_accuracy: 0.7344
# Epoch 11/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8404 - accuracy: 0.7413 - val_loss: 0.8266 - val_accuracy: 0.7407
# Epoch 12/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8179 - accuracy: 0.7483 - val_loss: 0.8055 - val_accuracy: 0.7478
# Epoch 13/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7948 - accuracy: 0.7509 - val_loss: 0.7798 - val_accuracy: 0.7562
# Epoch 14/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7718 - accuracy: 0.7587 - val_loss: 0.7577 - val_accuracy: 0.7666
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7514 - accuracy: 0.7627 - val_loss: 0.7367 - val_accuracy: 0.7699
# Epoch 16/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7325 - accuracy: 0.7669 - val_loss: 0.7175 - val_accuracy: 0.7775
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7151 - accuracy: 0.7691 - val_loss: 0.7005 - val_accuracy: 0.7762
# Epoch 18/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6992 - accuracy: 0.7730 - val_loss: 0.6850 - val_accuracy: 0.7783
# Epoch 19/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6855 - accuracy: 0.7746 - val_loss: 0.6708 - val_accuracy: 0.7812
# Epoch 20/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6722 - accuracy: 0.7781 - val_loss: 0.6572 - val_accuracy: 0.7887
# Epoch 21/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6600 - accuracy: 0.7805 - val_loss: 0.6463 - val_accuracy: 0.7879
# Epoch 22/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6496 - accuracy: 0.7848 - val_loss: 0.6351 - val_accuracy: 0.7891
# Epoch 23/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6398 - accuracy: 0.7856 - val_loss: 0.6244 - val_accuracy: 0.7929
# Epoch 24/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6309 - accuracy: 0.7893 - val_loss: 0.6151 - val_accuracy: 0.7946
# Epoch 25/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6229 - accuracy: 0.7895 - val_loss: 0.6052 - val_accuracy: 0.7979
# Epoch 26/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6154 - accuracy: 0.7919 - val_loss: 0.5974 - val_accuracy: 0.8025
# Epoch 27/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6084 - accuracy: 0.7940 - val_loss: 0.5901 - val_accuracy: 0.8033
# Epoch 28/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6022 - accuracy: 0.7980 - val_loss: 0.5837 - val_accuracy: 0.8075
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5962 - accuracy: 0.7982 - val_loss: 0.5770 - val_accuracy: 0.8088
# Epoch 30/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5912 - accuracy: 0.8014 - val_loss: 0.5709 - val_accuracy: 0.8109
# Epoch 31/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5858 - accuracy: 0.8013 - val_loss: 0.5646 - val_accuracy: 0.8117
# Epoch 32/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5812 - accuracy: 0.8039 - val_loss: 0.5599 - val_accuracy: 0.8129
# Epoch 33/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5763 - accuracy: 0.8051 - val_loss: 0.5547 - val_accuracy: 0.8167
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5722 - accuracy: 0.8063 - val_loss: 0.5516 - val_accuracy: 0.8142
# Epoch 35/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5685 - accuracy: 0.8094 - val_loss: 0.5456 - val_accuracy: 0.8184
# Epoch 36/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5652 - accuracy: 0.8097 - val_loss: 0.5430 - val_accuracy: 0.8171
# Epoch 37/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5621 - accuracy: 0.8105 - val_loss: 0.5379 - val_accuracy: 0.8205
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5597 - accuracy: 0.8099 - val_loss: 0.5380 - val_accuracy: 0.8159
# Epoch 39/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5563 - accuracy: 0.8127 - val_loss: 0.5326 - val_accuracy: 0.8230
# Epoch 40/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5539 - accuracy: 0.8136 - val_loss: 0.5283 - val_accuracy: 0.8251
# Epoch 41/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5512 - accuracy: 0.8172 - val_loss: 0.5253 - val_accuracy: 0.8267
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5489 - accuracy: 0.8160 - val_loss: 0.5228 - val_accuracy: 0.8263
# Epoch 43/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5468 - accuracy: 0.8185 - val_loss: 0.5202 - val_accuracy: 0.8276
# Epoch 44/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5449 - accuracy: 0.8172 - val_loss: 0.5185 - val_accuracy: 0.8263
# Epoch 45/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.5427 - accuracy: 0.8189 - val_loss: 0.5157 - val_accuracy: 0.8296
# Epoch 46/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5411 - accuracy: 0.8192 - val_loss: 0.5156 - val_accuracy: 0.8267
# Epoch 47/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.5394 - accuracy: 0.8198 - val_loss: 0.5105 - val_accuracy: 0.8305
# Epoch 48/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5377 - accuracy: 0.8212 - val_loss: 0.5100 - val_accuracy: 0.8322
# Epoch 49/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5356 - accuracy: 0.8210 - val_loss: 0.5088 - val_accuracy: 0.8317
# Epoch 50/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.5342 - accuracy: 0.8213 - val_loss: 0.5054 - val_accuracy: 0.8326
# Epoch 51/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.5324 - accuracy: 0.8243 - val_loss: 0.5033 - val_accuracy: 0.8347
# Epoch 52/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.5314 - accuracy: 0.8230 - val_loss: 0.5013 - val_accuracy: 0.8342
# Epoch 53/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5295 - accuracy: 0.8259 - val_loss: 0.5000 - val_accuracy: 0.8342
# Epoch 54/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.5295 - accuracy: 0.8237 - val_loss: 0.4982 - val_accuracy: 0.8363
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5271 - accuracy: 0.8260 - val_loss: 0.4973 - val_accuracy: 0.8355
# Epoch 56/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5255 - accuracy: 0.8269 - val_loss: 0.4949 - val_accuracy: 0.8376
# Epoch 57/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5254 - accuracy: 0.8273 - val_loss: 0.4937 - val_accuracy: 0.8392
# Epoch 58/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5228 - accuracy: 0.8274 - val_loss: 0.4931 - val_accuracy: 0.8376
# Epoch 59/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5221 - accuracy: 0.8263 - val_loss: 0.4917 - val_accuracy: 0.8380
# Epoch 60/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5208 - accuracy: 0.8278 - val_loss: 0.4897 - val_accuracy: 0.8401
# Epoch 61/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5199 - accuracy: 0.8301 - val_loss: 0.4880 - val_accuracy: 0.8426
# Epoch 62/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5183 - accuracy: 0.8293 - val_loss: 0.4896 - val_accuracy: 0.8355
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5178 - accuracy: 0.8296 - val_loss: 0.4858 - val_accuracy: 0.8418
# Epoch 64/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 0.8320 - val_loss: 0.4860 - val_accuracy: 0.8397
# Epoch 65/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5150 - accuracy: 0.8311 - val_loss: 0.4829 - val_accuracy: 0.8438
# Epoch 66/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5143 - accuracy: 0.8317 - val_loss: 0.4837 - val_accuracy: 0.8409
# Epoch 67/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5124 - accuracy: 0.8328 - val_loss: 0.4852 - val_accuracy: 0.8372
# Epoch 68/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5121 - accuracy: 0.8324 - val_loss: 0.4821 - val_accuracy: 0.8397
# Epoch 69/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5109 - accuracy: 0.8326 - val_loss: 0.4791 - val_accuracy: 0.8455
# Epoch 70/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5093 - accuracy: 0.8342 - val_loss: 0.4765 - val_accuracy: 0.8493
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5084 - accuracy: 0.8333 - val_loss: 0.4759 - val_accuracy: 0.8463
# Epoch 72/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5076 - accuracy: 0.8356 - val_loss: 0.4741 - val_accuracy: 0.8497
# Epoch 73/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5061 - accuracy: 0.8349 - val_loss: 0.4758 - val_accuracy: 0.8426
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5056 - accuracy: 0.8350 - val_loss: 0.4738 - val_accuracy: 0.8451
# Epoch 75/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5048 - accuracy: 0.8351 - val_loss: 0.4712 - val_accuracy: 0.8501
# Epoch 76/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5035 - accuracy: 0.8365 - val_loss: 0.4735 - val_accuracy: 0.8434
# Epoch 77/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5024 - accuracy: 0.8379 - val_loss: 0.4689 - val_accuracy: 0.8539
# Epoch 78/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5015 - accuracy: 0.8364 - val_loss: 0.4686 - val_accuracy: 0.8497
# Epoch 79/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5008 - accuracy: 0.8374 - val_loss: 0.4673 - val_accuracy: 0.8509
# Epoch 80/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4993 - accuracy: 0.8381 - val_loss: 0.4659 - val_accuracy: 0.8518
# Epoch 81/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4985 - accuracy: 0.8388 - val_loss: 0.4648 - val_accuracy: 0.8526
# Epoch 82/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4977 - accuracy: 0.8386 - val_loss: 0.4633 - val_accuracy: 0.8555
# Epoch 83/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4971 - accuracy: 0.8401 - val_loss: 0.4636 - val_accuracy: 0.8489
# Epoch 84/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.8396 - val_loss: 0.4621 - val_accuracy: 0.8522
# Epoch 85/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4949 - accuracy: 0.8410 - val_loss: 0.4633 - val_accuracy: 0.8463
# Epoch 86/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4941 - accuracy: 0.8395 - val_loss: 0.4629 - val_accuracy: 0.8476
# Epoch 87/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4933 - accuracy: 0.8399 - val_loss: 0.4589 - val_accuracy: 0.8534
# Epoch 88/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4923 - accuracy: 0.8416 - val_loss: 0.4603 - val_accuracy: 0.8489
# Epoch 89/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.8409 - val_loss: 0.4570 - val_accuracy: 0.8543
# Epoch 90/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4902 - accuracy: 0.8426 - val_loss: 0.4562 - val_accuracy: 0.8576
# Epoch 91/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4896 - accuracy: 0.8430 - val_loss: 0.4544 - val_accuracy: 0.8589
# Epoch 92/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4891 - accuracy: 0.8425 - val_loss: 0.4552 - val_accuracy: 0.8501
# Epoch 93/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4877 - accuracy: 0.8431 - val_loss: 0.4534 - val_accuracy: 0.8551
# Epoch 94/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4871 - accuracy: 0.8422 - val_loss: 0.4555 - val_accuracy: 0.8505
# Epoch 95/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4863 - accuracy: 0.8439 - val_loss: 0.4513 - val_accuracy: 0.8576
# Epoch 96/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4857 - accuracy: 0.8445 - val_loss: 0.4500 - val_accuracy: 0.8605
# Epoch 97/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4844 - accuracy: 0.8454 - val_loss: 0.4493 - val_accuracy: 0.8585
# Epoch 98/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4835 - accuracy: 0.8440 - val_loss: 0.4484 - val_accuracy: 0.8601
# Epoch 99/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.4826 - accuracy: 0.8466 - val_loss: 0.4472 - val_accuracy: 0.8618
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4817 - accuracy: 0.8464 - val_loss: 0.4463 - val_accuracy: 0.8610
# 94/94 [==============================] - 0s 1ms/step
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.8383
# Test Accuracy: 0.8383433818817139
